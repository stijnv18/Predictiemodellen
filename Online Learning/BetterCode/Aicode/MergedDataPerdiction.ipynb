# %%
import pandas as pd
from river import compose
from river import linear_model
from river import metrics
from river import preprocessing
from river import stream
from sklearn.feature_selection import SelectKBest, f_regression
import matplotlib.pyplot as plt
import numpy as np
from river import evaluate
from river import optim
import datetime as dt

# %%
# Load the data
df = pd.read_csv('merged_data.csv')


# Convert the 'utc_timestamp' column to datetime
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Drop the first row
df = df.dropna()

df['day_of_week'] = df['DateTime'].dt.dayofweek
df['hour_of_day'] = df['DateTime'].dt.hour
df['month'] = df['DateTime'].dt.month

df

#plot the data
plt.plot(df['DateTime'], df['MeanEnergyConsumption'])

# %%
#check for break in timestamps
import pandas as pd

# Assuming df is your DataFrame and 'timestamp' is your timestamp column
df = df.sort_values('DateTime')

# Calculate the difference between current and previous timestamp
df['time_diff'] = df['DateTime'].diff()

# Define a threshold for a break, e.g., 1 hour
threshold = pd.Timedelta(hours=1)

# Check if there are any breaks
has_breaks = any(df['time_diff'] > threshold)

print(f"Data has breaks: {has_breaks}")
# Out:
# Data has breaks: False

# %%
#df['MeanEnergyConsumption'].plot()

#drop the utc_timestamp column
#df = df.drop('utc_timestamp', axis=1)

stream = iter(df.itertuples(index=False))
stream = iter([(x._asdict(), y) for x, y in zip(df.drop('MeanEnergyConsumption', axis=1).itertuples(index=False), df['MeanEnergyConsumption'])])
print(next(stream))
# Out:
# ({'DateTime': Timestamp('2011-11-23 09:00:00'), 'temperature_2m': 4.25, 'precipitation': 0.0, 'cloud_cover': 30.300001, 'cloud_cover_low': 1.0, 'cloud_cover_mid': 0.0, 'cloud_cover_high': 98.0, 'is_day': 1.0, 'sunshine_duration': 2924.7007, 'day_of_week': 2, 'hour_of_day': 9, 'month': 11}, 0.355)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates



plt.plot(df['DateTime'], df['MeanEnergyConsumption'])

#model = compose.Select('hour_of_day', 'month', 'day_of_week')
model = compose.Select('hour_of_day', 'month', 'day_of_week','temperature_2m', 'precipitation','cloud_cover','cloud_cover_low','cloud_cover_mid','cloud_cover_high','is_day','sunshine_duration')
model |= preprocessing.StandardScaler()

model |= linear_model.LinearRegression(optimizer=optim.SGD(0.00071))

metric = metrics.MAE()

steps = evaluate.iter_progressive_val_score(
    dataset=stream,
    model=model,
    metric=metrics.MAE(),
    moment='DateTime',
    delay=dt.timedelta(days=7),
    step=1,
    yield_predictions=True,
)
print(model['LinearRegression'].weights)
print(model['LinearRegression'].intercept)
print(model['LinearRegression'])
start_date =  df['DateTime'].min()
end_date =  df['DateTime'].max()
# Initialize lists to store the predictions and their timestamps
predictions = []
timestamps = pd.date_range(start=start_date, end=end_date, freq='1H')
#remove the first timestamp
timestamps = timestamps[1:]
Mea_overtime = []

length = 0
for step in steps:
    print(step)
    length += 1
    predictions.append(step["Prediction"])
    #print(step["MAE"])
    Mea_overtime.append(str(step["MAE"]).split(" ")[1])
    #print(model['LinearRegression'].weights)
    #print(model['LinearRegression'].intercept)
    
#convert list of strings to list of floats
Mea_overtime = [float(i) for i in Mea_overtime]



# Plot the predictions
fig, ax = plt.subplots()
# Also plot the actual values with transparency and a label for the legend
ax.plot_date(mdates.date2num(df['DateTime']), df['MeanEnergyConsumption'], linestyle='-', marker=None, alpha=0.5, label='Actual Values')
# Plot the predictions with transparency and a label for the legend
ax.plot_date(mdates.date2num(timestamps), predictions, linestyle='-', marker=None, alpha=0.5, label='Predictions')
#add title
ax.set_title('Energy Consumption over Time with a 7-day Delay (linear regression sgd(0.00071))')
# Label the y-axis
ax.set_ylabel('Energy Consumption (kWh)')
# Set the x-axis label
ax.set_xlabel('Date')

# Rotate date labels automatically
fig.autofmt_xdate()
# Add a legend
ax.legend()
plt.show()




#plotting of the predictions and actual values for a week

# Define the start and end dates
start_date = pd.to_datetime('2013-01-01')
end_date = start_date + pd.DateOffset(weeks=1)


df['DateTime'] = pd.to_datetime(df['DateTime'])

# Filter the data
week_data = df[(df['DateTime'] >= start_date) & (df['DateTime'] < end_date)]

#combine the predictions and timestamps into a dataframe
df_prediction = pd.DataFrame({'DateTime': timestamps, 'Predictions': predictions})

#convert datetime to datetime object
df_prediction['DateTime'] = pd.to_datetime(df_prediction['DateTime'])
week_predictions = df_prediction[(df_prediction['DateTime'] >= start_date) & (df_prediction['DateTime'] < end_date)]
fig, ax = plt.subplots()

# Also plot the actual values with transparency and a label for the legend
ax.plot_date(mdates.date2num(week_data['DateTime']), week_data['MeanEnergyConsumption'], linestyle='-', marker=None, label='Actual Values')

# Plot the predictions with transparency and a label for the legend
ax.plot_date(mdates.date2num(week_predictions['DateTime']), week_predictions['Predictions'], linestyle='-', marker=None, label='Predictions')

# Label the y-axis
ax.set_ylabel('Energy Consumption (kWh)')
# Set the x-axis label
ax.set_xlabel('Date')
# Add a legend
ax.legend()
#add title
ax.set_title('Energy Consumption 7-day Delay (linear regression sgd(0.00071))')

# Rotate date labels automatically
fig.autofmt_xdate()

plt.show()











# Plot the MAE
#fig, ax = plt.subplots()
#ax.plot_date(mdates.date2num(timestamps), Mea_overtime, linestyle='-', marker=None)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
#ax.set_ylim(-0.25,0.5)
#plt.show()
# Out:
# {}
# 0.0
# LinearRegression
# {'MAE': MAE: 0.1745, 'Step': 1, 'Prediction': 0.0}
# {'MAE': MAE: 0.15425, 'Step': 2, 'Prediction': 0.0}
# {'MAE': MAE: 0.253452, 'Step': 3, 'Prediction': 0.0}
# {'MAE': MAE: 0.262089, 'Step': 4, 'Prediction': 0.0}
# {'MAE': MAE: 0.269508, 'Step': 5, 'Prediction': 0.0}
# {'MAE': MAE: 0.261923, 'Step': 6, 'Prediction': 0.0}
# {'MAE': MAE: 0.246454, 'Step': 7, 'Prediction': 0.0}
# {'MAE': MAE: 0.247726, 'Step': 8, 'Prediction': 0.0}
# {'MAE': MAE: 0.251474, 'Step': 9, 'Prediction': 0.0}
# {'MAE': MAE: 0.260608, 'Step': 10, 'Prediction': 0.0}
# {'MAE': MAE: 0.281694, 'Step': 11, 'Prediction': 0.0}
# {'MAE': MAE: 0.290568, 'Step': 12, 'Prediction': 0.0}
# {'MAE': MAE: 0.298958, 'Step': 13, 'Prediction': 0.0}
# {'MAE': MAE: 0.296597, 'Step': 14, 'Prediction': 0.0}
# {'MAE': MAE: 0.290497, 'Step': 15, 'Prediction': 0.0}
# {'MAE': MAE: 0.291062, 'Step': 16, 'Prediction': 0.0}
# {'MAE': MAE: 0.286337, 'Step': 17, 'Prediction': 0.0}
# {'MAE': MAE: 0.279242, 'Step': 18, 'Prediction': 0.0}
# {'MAE': MAE: 0.272215, 'Step': 19, 'Prediction': 0.0}
# {'MAE': MAE: 0.264431, 'Step': 20, 'Prediction': 0.0}
# {'MAE': MAE: 0.258372, 'Step': 21, 'Prediction': 0.0}
# {'MAE': MAE: 0.254545, 'Step': 22, 'Prediction': 0.0}
# {'MAE': MAE: 0.250865, 'Step': 23, 'Prediction': 0.0}
# {'MAE': MAE: 0.246379, 'Step': 24, 'Prediction': 0.0}
# {'MAE': MAE: 0.245893, 'Step': 25, 'Prediction': 0.0}
# {'MAE': MAE: 0.243692, 'Step': 26, 'Prediction': 0.0}
# {'MAE': MAE: 0.24333, 'Step': 27, 'Prediction': 0.0}
# {'MAE': MAE: 0.242292, 'Step': 28, 'Prediction': 0.0}
# {'MAE': MAE: 0.240988, 'Step': 29, 'Prediction': 0.0}
# {'MAE': MAE: 0.24037, 'Step': 30, 'Prediction': 0.0}
# {'MAE': MAE: 0.238433, 'Step': 31, 'Prediction': 0.0}
# {'MAE': MAE: 0.239716, 'Step': 32, 'Prediction': 0.0}
# {'MAE': MAE: 0.240916, 'Step': 33, 'Prediction': 0.0}
# {'MAE': MAE: 0.244996, 'Step': 34, 'Prediction': 0.0}
# {'MAE': MAE: 0.248302, 'Step': 35, 'Prediction': 0.0}
# {'MAE': MAE: 0.251424, 'Step': 36, 'Prediction': 0.0}
# {'MAE': MAE: 0.254947, 'Step': 37, 'Prediction': 0.0}
# {'MAE': MAE: 0.255147, 'Step': 38, 'Prediction': 0.0}
# {'MAE': MAE: 0.254652, 'Step': 39, 'Prediction': 0.0}
# {'MAE': MAE: 0.25554, 'Step': 40, 'Prediction': 0.0}
# {'MAE': MAE: 0.256534, 'Step': 41, 'Prediction': 0.0}
# {'MAE': MAE: 0.257004, 'Step': 42, 'Prediction': 0.0}
# {'MAE': MAE: 0.255613, 'Step': 43, 'Prediction': 0.0}
# {'MAE': MAE: 0.253351, 'Step': 44, 'Prediction': 0.0}
# {'MAE': MAE: 0.251434, 'Step': 45, 'Prediction': 0.0}
# {'MAE': MAE: 0.249297, 'Step': 46, 'Prediction': 0.0}
# {'MAE': MAE: 0.248031, 'Step': 47, 'Prediction': 0.0}
# {'MAE': MAE: 0.247023, 'Step': 48, 'Prediction': 0.0}
# {'MAE': MAE: 0.245727, 'Step': 49, 'Prediction': 0.0}
# {'MAE': MAE: 0.243703, 'Step': 50, 'Prediction': 0.0}
# {'MAE': MAE: 0.242971, 'Step': 51, 'Prediction': 0.0}
# {'MAE': MAE: 0.242091, 'Step': 52, 'Prediction': 0.0}
# {'MAE': MAE: 0.241586, 'Step': 53, 'Prediction': 0.0}
# {'MAE': MAE: 0.241323, 'Step': 54, 'Prediction': 0.0}
# {'MAE': MAE: 0.240066, 'Step': 55, 'Prediction': 0.0}
# {'MAE': MAE: 0.240854, 'Step': 56, 'Prediction': 0.0}
# {'MAE': MAE: 0.239956, 'Step': 57, 'Prediction': 0.0}
# {'MAE': MAE: 0.240541, 'Step': 58, 'Prediction': 0.0}
# {'MAE': MAE: 0.241541, 'Step': 59, 'Prediction': 0.0}
# {'MAE': MAE: 0.24245, 'Step': 60, 'Prediction': 0.0}
# {'MAE': MAE: 0.244092, 'Step': 61, 'Prediction': 0.0}
# {'MAE': MAE: 0.244825, 'Step': 62, 'Prediction': 0.0}
# {'MAE': MAE: 0.244849, 'Step': 63, 'Prediction': 0.0}
# {'MAE': MAE: 0.24513, 'Step': 64, 'Prediction': 0.0}
# {'MAE': MAE: 0.244945, 'Step': 65, 'Prediction': 0.0}
# {'MAE': MAE: 0.244106, 'Step': 66, 'Prediction': 0.0}
# {'MAE': MAE: 0.242089, 'Step': 67, 'Prediction': 0.0}
# {'MAE': MAE: 0.240503, 'Step': 68, 'Prediction': 0.0}
# {'MAE': MAE: 0.239272, 'Step': 69, 'Prediction': 0.0}
# {'MAE': MAE: 0.237945, 'Step': 70, 'Prediction': 0.0}
# {'MAE': MAE: 0.237056, 'Step': 71, 'Prediction': 0.0}
# {'MAE': MAE: 0.235843, 'Step': 72, 'Prediction': 0.0}
# {'MAE': MAE: 0.234903, 'Step': 73, 'Prediction': 0.0}
# {'MAE': MAE: 0.23468, 'Step': 74, 'Prediction': 0.0}
# {'MAE': MAE: 0.23395, 'Step': 75, 'Prediction': 0.0}
# {'MAE': MAE: 0.23358, 'Step': 76, 'Prediction': 0.0}
# {'MAE': MAE: 0.233899, 'Step': 77, 'Prediction': 0.0}
# {'MAE': MAE: 0.234654, 'Step': 78, 'Prediction': 0.0}
# {'MAE': MAE: 0.235163, 'Step': 79, 'Prediction': 0.0}
# {'MAE': MAE: 0.236122, 'Step': 80, 'Prediction': 0.0}
# {'MAE': MAE: 0.237155, 'Step': 81, 'Prediction': 0.0}
# {'MAE': MAE: 0.239065, 'Step': 82, 'Prediction': 0.0}
# {'MAE': MAE: 0.240432, 'Step': 83, 'Prediction': 0.0}
# {'MAE': MAE: 0.24177, 'Step': 84, 'Prediction': 0.0}
# {'MAE': MAE: 0.243122, 'Step': 85, 'Prediction': 0.0}
# {'MAE': MAE: 0.244095, 'Step': 86, 'Prediction': 0.0}
# {'MAE': MAE: 0.243552, 'Step': 87, 'Prediction': 0.0}
# {'MAE': MAE: 0.243743, 'Step': 88, 'Prediction': 0.0}
# {'MAE': MAE: 0.24356, 'Step': 89, 'Prediction': 0.0}
# {'MAE': MAE: 0.242681, 'Step': 90, 'Prediction': 0.0}
# {'MAE': MAE: 0.241634, 'Step': 91, 'Prediction': 0.0}
# {'MAE': MAE: 0.240791, 'Step': 92, 'Prediction': 0.0}
# {'MAE': MAE: 0.239828, 'Step': 93, 'Prediction': 0.0}
# {'MAE': MAE: 0.239025, 'Step': 94, 'Prediction': 0.0}
# {'MAE': MAE: 0.238172, 'Step': 95, 'Prediction': 0.0}
# {'MAE': MAE: 0.237425, 'Step': 96, 'Prediction': 0.0}
# {'MAE': MAE: 0.23682, 'Step': 97, 'Prediction': 0.0}
# {'MAE': MAE: 0.23663, 'Step': 98, 'Prediction': 0.0}
# {'MAE': MAE: 0.236692, 'Step': 99, 'Prediction': 0.0}
# {'MAE': MAE: 0.236676, 'Step': 100, 'Prediction': 0.0}
# {'MAE': MAE: 0.236436, 'Step': 101, 'Prediction': 0.0}
# {'MAE': MAE: 0.236817, 'Step': 102, 'Prediction': 0.0}
# {'MAE': MAE: 0.237392, 'Step': 103, 'Prediction': 0.0}
# {'MAE': MAE: 0.238457, 'Step': 104, 'Prediction': 0.0}
# {'MAE': MAE: 0.239117, 'Step': 105, 'Prediction': 0.0}
# {'MAE': MAE: 0.239996, 'Step': 106, 'Prediction': 0.0}
# {'MAE': MAE: 0.240586, 'Step': 107, 'Prediction': 0.0}
# {'MAE': MAE: 0.240972, 'Step': 108, 'Prediction': 0.0}
# {'MAE': MAE: 0.241187, 'Step': 109, 'Prediction': 0.0}
# {'MAE': MAE: 0.24131, 'Step': 110, 'Prediction': 0.0}
# {'MAE': MAE: 0.240643, 'Step': 111, 'Prediction': 0.0}
# {'MAE': MAE: 0.240372, 'Step': 112, 'Prediction': 0.0}
# {'MAE': MAE: 0.240061, 'Step': 113, 'Prediction': 0.0}
# {'MAE': MAE: 0.23952, 'Step': 114, 'Prediction': 0.0}
# {'MAE': MAE: 0.238593, 'Step': 115, 'Prediction': 0.0}
# {'MAE': MAE: 0.237555, 'Step': 116, 'Prediction': 0.0}
# {'MAE': MAE: 0.236597, 'Step': 117, 'Prediction': 0.0}
# {'MAE': MAE: 0.236162, 'Step': 118, 'Prediction': 0.0}
# {'MAE': MAE: 0.23601, 'Step': 119, 'Prediction': 0.0}
# {'MAE': MAE: 0.235601, 'Step': 120, 'Prediction': 0.0}
# {'MAE': MAE: 0.235123, 'Step': 121, 'Prediction': 0.0}
# {'MAE': MAE: 0.23486, 'Step': 122, 'Prediction': 0.0}
# {'MAE': MAE: 0.234468, 'Step': 123, 'Prediction': 0.0}
# {'MAE': MAE: 0.234212, 'Step': 124, 'Prediction': 0.0}
# {'MAE': MAE: 0.233846, 'Step': 125, 'Prediction': 0.0}
# {'MAE': MAE: 0.233809, 'Step': 126, 'Prediction': 0.0}
# {'MAE': MAE: 0.233556, 'Step': 127, 'Prediction': 0.0}
# {'MAE': MAE: 0.233812, 'Step': 128, 'Prediction': 0.0}
# {'MAE': MAE: 0.234499, 'Step': 129, 'Prediction': 0.0}
# {'MAE': MAE: 0.235378, 'Step': 130, 'Prediction': 0.0}
# {'MAE': MAE: 0.236546, 'Step': 131, 'Prediction': 0.0}
# {'MAE': MAE: 0.237108, 'Step': 132, 'Prediction': 0.0}
# {'MAE': MAE: 0.237476, 'Step': 133, 'Prediction': 0.0}
# {'MAE': MAE: 0.237595, 'Step': 134, 'Prediction': 0.0}
# {'MAE': MAE: 0.237317, 'Step': 135, 'Prediction': 0.0}
# {'MAE': MAE: 0.237004, 'Step': 136, 'Prediction': 0.0}
# {'MAE': MAE: 0.236426, 'Step': 137, 'Prediction': 0.0}
# {'MAE': MAE: 0.235719, 'Step': 138, 'Prediction': 0.0}
# {'MAE': MAE: 0.23504, 'Step': 139, 'Prediction': 0.0}
# {'MAE': MAE: 0.234143, 'Step': 140, 'Prediction': 0.0}
# {'MAE': MAE: 0.233396, 'Step': 141, 'Prediction': 0.0}
# {'MAE': MAE: 0.232845, 'Step': 142, 'Prediction': 0.0}
# {'MAE': MAE: 0.232804, 'Step': 143, 'Prediction': 0.0}
# {'MAE': MAE: 0.232369, 'Step': 144, 'Prediction': 0.0}
# {'MAE': MAE: 0.231829, 'Step': 145, 'Prediction': 0.0}
# {'MAE': MAE: 0.231199, 'Step': 146, 'Prediction': 0.0}
# {'MAE': MAE: 0.230686, 'Step': 147, 'Prediction': 0.0}
# {'MAE': MAE: 0.230591, 'Step': 148, 'Prediction': 0.0}
# {'MAE': MAE: 0.230374, 'Step': 149, 'Prediction': 0.0}
# {'MAE': MAE: 0.230027, 'Step': 150, 'Prediction': 0.0}
# {'MAE': MAE: 0.229836, 'Step': 151, 'Prediction': 0.0}
# {'MAE': MAE: 0.229909, 'Step': 152, 'Prediction': 0.0}
# {'MAE': MAE: 0.230147, 'Step': 153, 'Prediction': 0.0}
# {'MAE': MAE: 0.230463, 'Step': 154, 'Prediction': 0.0}
# {'MAE': MAE: 0.231153, 'Step': 155, 'Prediction': 0.0}
# {'MAE': MAE: 0.231778, 'Step': 156, 'Prediction': 0.0}
# {'MAE': MAE: 0.232303, 'Step': 157, 'Prediction': 0.0}
# {'MAE': MAE: 0.232335, 'Step': 158, 'Prediction': 0.0}
# {'MAE': MAE: 0.232227, 'Step': 159, 'Prediction': 0.0}
# {'MAE': MAE: 0.232118, 'Step': 160, 'Prediction': 0.0}
# {'MAE': MAE: 0.231933, 'Step': 161, 'Prediction': 0.0}
# {'MAE': MAE: 0.231383, 'Step': 162, 'Prediction': 0.0}
# {'MAE': MAE: 0.230701, 'Step': 163, 'Prediction': 0.0}
# {'MAE': MAE: 0.229968, 'Step': 164, 'Prediction': 0.0}
# {'MAE': MAE: 0.229383, 'Step': 165, 'Prediction': 0.0}
# {'MAE': MAE: 0.228941, 'Step': 166, 'Prediction': 0.0}
# {'MAE': MAE: 0.229061, 'Step': 167, 'Prediction': 0.0}
# {'MAE': MAE: 0.228758, 'Step': 168, 'Prediction': 0.0}
# {'MAE': MAE: 0.228433, 'Step': 169, 'Prediction': 0.00349}
# {'MAE': MAE: 0.227943, 'Step': 170, 'Prediction': 0.018762027599999995}
# {'MAE': MAE: 0.227891, 'Step': 171, 'Prediction': -0.011857401825243202}
# {'MAE': MAE: 0.227788, 'Step': 172, 'Prediction': -0.02816411257741443}
# {'MAE': MAE: 0.22735, 'Step': 173, 'Prediction': 0.03357580848838538}
# {'MAE': MAE: 0.226883, 'Step': 174, 'Prediction': 0.004656362817996966}
# {'MAE': MAE: 0.226526, 'Step': 175, 'Prediction': 0.04217816276464383}
# {'MAE': MAE: 0.22634, 'Step': 176, 'Prediction': 0.04890855777341331}
# {'MAE': MAE: 0.226347, 'Step': 177, 'Prediction': 0.05229719643114566}
# {'MAE': MAE: 0.226262, 'Step': 178, 'Prediction': 0.05912583274004789}
# {'MAE': MAE: 0.226282, 'Step': 179, 'Prediction': 0.07133151313302119}
# {'MAE': MAE: 0.226376, 'Step': 180, 'Prediction': 0.08422101193214487}
# {'MAE': MAE: 0.225962, 'Step': 181, 'Prediction': 0.09657628076504442}
# {'MAE': MAE: 0.225453, 'Step': 182, 'Prediction': 0.10156365018585915}
# {'MAE': MAE: 0.224797, 'Step': 183, 'Prediction': 0.07653987214995413}
# {'MAE': MAE: 0.224011, 'Step': 184, 'Prediction': 0.08781690212486971}
# {'MAE': MAE: 0.223237, 'Step': 185, 'Prediction': 0.09055052985640903}
# {'MAE': MAE: 0.22227, 'Step': 186, 'Prediction': 0.0944085062584421}
# {'MAE': MAE: 0.221116, 'Step': 187, 'Prediction': 0.1139125178434716}
# {'MAE': MAE: 0.220057, 'Step': 188, 'Prediction': 0.12311604246848558}
# {'MAE': MAE: 0.218937, 'Step': 189, 'Prediction': 0.128074421499172}
# {'MAE': MAE: 0.217947, 'Step': 190, 'Prediction': 0.13213428439240954}
# {'MAE': MAE: 0.217307, 'Step': 191, 'Prediction': 0.12473633160713432}
# {'MAE': MAE: 0.216504, 'Step': 192, 'Prediction': 0.12031583009918727}
# {'MAE': MAE: 0.215769, 'Step': 193, 'Prediction': 0.10412913451740657}
# {'MAE': MAE: 0.215234, 'Step': 194, 'Prediction': 0.08886660149232771}
# {'MAE': MAE: 0.21454, 'Step': 195, 'Prediction': 0.10344254069053237}
# {'MAE': MAE: 0.214062, 'Step': 196, 'Prediction': 0.10148528168440976}
# {'MAE': MAE: 0.213457, 'Step': 197, 'Prediction': 0.11537369454534162}
# {'MAE': MAE: 0.212932, 'Step': 198, 'Prediction': 0.1194728802199216}
# {'MAE': MAE: 0.21239, 'Step': 199, 'Prediction': 0.12384140230533541}
# {'MAE': MAE: 0.211963, 'Step': 200, 'Prediction': 0.12634858486934847}
# {'MAE': MAE: 0.211881, 'Step': 201, 'Prediction': 0.12722789025109438}
# {'MAE': MAE: 0.211649, 'Step': 202, 'Prediction': 0.13228037606451254}
# {'MAE': MAE: 0.211692, 'Step': 203, 'Prediction': 0.1350524393323438}
# {'MAE': MAE: 0.211516, 'Step': 204, 'Prediction': 0.13772358162198797}
# {'MAE': MAE: 0.211143, 'Step': 205, 'Prediction': 0.1417557152919999}
# {'MAE': MAE: 0.210502, 'Step': 206, 'Prediction': 0.16209717510071214}
# {'MAE': MAE: 0.209738, 'Step': 207, 'Prediction': 0.14524300860092434}
# {'MAE': MAE: 0.208959, 'Step': 208, 'Prediction': 0.14307184760270555}
# {'MAE': MAE: 0.207975, 'Step': 209, 'Prediction': 0.14070179538482835}
# {'MAE': MAE: 0.207072, 'Step': 210, 'Prediction': 0.14042839023219483}
# {'MAE': MAE: 0.20623, 'Step': 211, 'Prediction': 0.13763966069186911}
# {'MAE': MAE: 0.205293, 'Step': 212, 'Prediction': 0.13387161162534306}
# {'MAE': MAE: 0.20434, 'Step': 213, 'Prediction': 0.13071737288430735}
# {'MAE': MAE: 0.203745, 'Step': 214, 'Prediction': 0.12849923905852567}
# {'MAE': MAE: 0.203468, 'Step': 215, 'Prediction': 0.11652994553282793}
# {'MAE': MAE: 0.203167, 'Step': 216, 'Prediction': 0.11172729027529396}
# {'MAE': MAE: 0.20283, 'Step': 217, 'Prediction': 0.11253093271741918}
# {'MAE': MAE: 0.202389, 'Step': 218, 'Prediction': 0.10860928760063657}
# {'MAE': MAE: 0.201831, 'Step': 219, 'Prediction': 0.11403460954261525}
# {'MAE': MAE: 0.201312, 'Step': 220, 'Prediction': 0.1260856482974769}
# {'MAE': MAE: 0.200669, 'Step': 221, 'Prediction': 0.14357860383485743}
# {'MAE': MAE: 0.200213, 'Step': 222, 'Prediction': 0.14750409670134523}
# {'MAE': MAE: 0.199734, 'Step': 223, 'Prediction': 0.15711437132533818}
# {'MAE': MAE: 0.199492, 'Step': 224, 'Prediction': 0.15788992375532465}
# {'MAE': MAE: 0.199333, 'Step': 225, 'Prediction': 0.16433152475322133}
# {'MAE': MAE: 0.199198, 'Step': 226, 'Prediction': 0.17211780531665705}
# {'MAE': MAE: 0.198942, 'Step': 227, 'Prediction': 0.17757628536956066}
# {'MAE': MAE: 0.198576, 'Step': 228, 'Prediction': 0.18734964718174493}
# {'MAE': MAE: 0.197964, 'Step': 229, 'Prediction': 0.19642626153038883}
# {'MAE': MAE: 0.197287, 'Step': 230, 'Prediction': 0.2077935641491535}
# {'MAE': MAE: 0.196464, 'Step': 231, 'Prediction': 0.19351875523158796}
# {'MAE': MAE: 0.195713, 'Step': 232, 'Prediction': 0.19338794965852502}
# {'MAE': MAE: 0.195092, 'Step': 233, 'Prediction': 0.19465444482345232}
# {'MAE': MAE: 0.194509, 'Step': 234, 'Prediction': 0.19748454331236293}
# {'MAE': MAE: 0.194006, 'Step': 235, 'Prediction': 0.1979609660292618}
# {'MAE': MAE: 0.193555, 'Step': 236, 'Prediction': 0.21147582131332507}
# {'MAE': MAE: 0.19306, 'Step': 237, 'Prediction': 0.2081821095569132}
# {'MAE': MAE: 0.192447, 'Step': 238, 'Prediction': 0.20850176244804508}
# {'MAE': MAE: 0.191722, 'Step': 239, 'Prediction': 0.20074786389000004}
# {'MAE': MAE: 0.19106, 'Step': 240, 'Prediction': 0.20264992178844662}
# {'MAE': MAE: 0.190312, 'Step': 241, 'Prediction': 0.19260562617140917}
# {'MAE': MAE: 0.189719, 'Step': 242, 'Prediction': 0.17720506192678265}
# {'MAE': MAE: 0.189552, 'Step': 243, 'Prediction': 0.17638906690657435}
# {'MAE': MAE: 0.18922, 'Step': 244, 'Prediction': 0.1776484709960018}
# {'MAE': MAE: 0.189009, 'Step': 245, 'Prediction': 0.18023546057317003}
# {'MAE': MAE: 0.188545, 'Step': 246, 'Prediction': 0.18457056100197725}
# {'MAE': MAE: 0.18789, 'Step': 247, 'Prediction': 0.2057766094186289}
# {'MAE': MAE: 0.187436, 'Step': 248, 'Prediction': 0.2076260501552996}
# {'MAE': MAE: 0.187153, 'Step': 249, 'Prediction': 0.2109606319322834}
# {'MAE': MAE: 0.187151, 'Step': 250, 'Prediction': 0.21967831407058233}
# {'MAE': MAE: 0.186927, 'Step': 251, 'Prediction': 0.2277525511621512}
# {'MAE': MAE: 0.186726, 'Step': 252, 'Prediction': 0.2357889931975008}
# {'MAE': MAE: 0.18631, 'Step': 253, 'Prediction': 0.23441725408447395}
# {'MAE': MAE: 0.185715, 'Step': 254, 'Prediction': 0.2274763352855439}
# {'MAE': MAE: 0.185062, 'Step': 255, 'Prediction': 0.203996048369577}
# {'MAE': MAE: 0.184398, 'Step': 256, 'Prediction': 0.2016341855269259}
# {'MAE': MAE: 0.183851, 'Step': 257, 'Prediction': 0.19959121377738426}
# {'MAE': MAE: 0.183337, 'Step': 258, 'Prediction': 0.1960843391474147}
# {'MAE': MAE: 0.1829, 'Step': 259, 'Prediction': 0.1926630751627543}
# {'MAE': MAE: 0.182479, 'Step': 260, 'Prediction': 0.1914976744442728}
# {'MAE': MAE: 0.182019, 'Step': 261, 'Prediction': 0.18923589062971133}
# {'MAE': MAE: 0.181403, 'Step': 262, 'Prediction': 0.18809299870942606}
# {'MAE': MAE: 0.180792, 'Step': 263, 'Prediction': 0.17395478608828982}
# {'MAE': MAE: 0.180353, 'Step': 264, 'Prediction': 0.17425318226449313}
# {'MAE': MAE: 0.179992, 'Step': 265, 'Prediction': 0.17763829178505883}
# {'MAE': MAE: 0.179571, 'Step': 266, 'Prediction': 0.17979952692399442}
# {'MAE': MAE: 0.17945, 'Step': 267, 'Prediction': 0.17879639718914353}
# {'MAE': MAE: 0.179409, 'Step': 268, 'Prediction': 0.18425490145706624}
# {'MAE': MAE: 0.179179, 'Step': 269, 'Prediction': 0.19081640245816955}
# {'MAE': MAE: 0.178972, 'Step': 270, 'Prediction': 0.189638109772268}
# {'MAE': MAE: 0.178781, 'Step': 271, 'Prediction': 0.2098651230135039}
# {'MAE': MAE: 0.178676, 'Step': 272, 'Prediction': 0.2275898237256095}
# {'MAE': MAE: 0.178735, 'Step': 273, 'Prediction': 0.22972359324398992}
# {'MAE': MAE: 0.178659, 'Step': 274, 'Prediction': 0.23201467079664398}
# {'MAE': MAE: 0.178486, 'Step': 275, 'Prediction': 0.23950073347977313}
# {'MAE': MAE: 0.178092, 'Step': 276, 'Prediction': 0.24335457998216434}
# {'MAE': MAE: 0.177684, 'Step': 277, 'Prediction': 0.2450987864760122}
# {'MAE': MAE: 0.177071, 'Step': 278, 'Prediction': 0.2463279818788724}
# {'MAE': MAE: 0.176624, 'Step': 279, 'Prediction': 0.1594668703454527}
# {'MAE': MAE: 0.17606, 'Step': 280, 'Prediction': 0.16600164306367776}
# {'MAE': MAE: 0.175499, 'Step': 281, 'Prediction': 0.16997743614653474}
# {'MAE': MAE: 0.174948, 'Step': 282, 'Prediction': 0.1728130594373349}
# {'MAE': MAE: 0.174495, 'Step': 283, 'Prediction': 0.17314638489318376}
# {'MAE': MAE: 0.173966, 'Step': 284, 'Prediction': 0.1728693291805122}
# {'MAE': MAE: 0.173356, 'Step': 285, 'Prediction': 0.17315361668591028}
# {'MAE': MAE: 0.173036, 'Step': 286, 'Prediction': 0.17607837176557817}
# {'MAE': MAE: 0.172926, 'Step': 287, 'Prediction': 0.16670834294424552}
# {'MAE': MAE: 0.172615, 'Step': 288, 'Prediction': 0.16343322392207998}
# {'MAE': MAE: 0.172152, 'Step': 289, 'Prediction': 0.15199295517912387}
# {'MAE': MAE: 0.171751, 'Step': 290, 'Prediction': 0.13912229832372694}
# {'MAE': MAE: 0.171393, 'Step': 291, 'Prediction': 0.14186454875453655}
# {'MAE': MAE: 0.170949, 'Step': 292, 'Prediction': 0.15038632294925516}
# {'MAE': MAE: 0.170519, 'Step': 293, 'Prediction': 0.1580870190352832}
# {'MAE': MAE: 0.170012, 'Step': 294, 'Prediction': 0.16597032012968843}
# {'MAE': MAE: 0.169558, 'Step': 295, 'Prediction': 0.20174724442586928}
# {'MAE': MAE: 0.169266, 'Step': 296, 'Prediction': 0.20504355031371715}
# {'MAE': MAE: 0.169133, 'Step': 297, 'Prediction': 0.20957800418297606}
# {'MAE': MAE: 0.16908, 'Step': 298, 'Prediction': 0.21413446528046193}
# {'MAE': MAE: 0.169161, 'Step': 299, 'Prediction': 0.21822746928154943}
# {'MAE': MAE: 0.168991, 'Step': 300, 'Prediction': 0.2205115806293279}
# {'MAE': MAE: 0.168732, 'Step': 301, 'Prediction': 0.21967883326696128}
# {'MAE': MAE: 0.168342, 'Step': 302, 'Prediction': 0.22204926521379126}
# {'MAE': MAE: 0.167813, 'Step': 303, 'Prediction': 0.192735178855177}
# {'MAE': MAE: 0.167305, 'Step': 304, 'Prediction': 0.1950084606844657}
# {'MAE': MAE: 0.166892, 'Step': 305, 'Prediction': 0.19692950113581645}
# {'MAE': MAE: 0.166525, 'Step': 306, 'Prediction': 0.19715230462197045}
# {'MAE': MAE: 0.166232, 'Step': 307, 'Prediction': 0.1981071848100206}
# {'MAE': MAE: 0.165881, 'Step': 308, 'Prediction': 0.20113547687690256}
# {'MAE': MAE: 0.165372, 'Step': 309, 'Prediction': 0.2009239190813414}
# {'MAE': MAE: 0.164917, 'Step': 310, 'Prediction': 0.20115005800001423}
# {'MAE': MAE: 0.16477, 'Step': 311, 'Prediction': 0.18984947604565083}
# {'MAE': MAE: 0.164416, 'Step': 312, 'Prediction': 0.18546118470854314}
# {'MAE': MAE: 0.164052, 'Step': 313, 'Prediction': 0.17916355215182148}
# {'MAE': MAE: 0.163719, 'Step': 314, 'Prediction': 0.16715645905364912}
# {'MAE': MAE: 0.163415, 'Step': 315, 'Prediction': 0.1599487115492568}
# {'MAE': MAE: 0.163155, 'Step': 316, 'Prediction': 0.15687674731670354}
# {'MAE': MAE: 0.16291, 'Step': 317, 'Prediction': 0.17159786645519848}
# {'MAE': MAE: 0.162584, 'Step': 318, 'Prediction': 0.17524339600652802}
# {'MAE': MAE: 0.16225, 'Step': 319, 'Prediction': 0.19499334530046988}
# {'MAE': MAE: 0.162001, 'Step': 320, 'Prediction': 0.21383107269215024}
# {'MAE': MAE: 0.161971, 'Step': 321, 'Prediction': 0.21875780450163798}
# {'MAE': MAE: 0.161856, 'Step': 322, 'Prediction': 0.22426592158654632}
# {'MAE': MAE: 0.161768, 'Step': 323, 'Prediction': 0.22745493253604382}
# {'MAE': MAE: 0.161521, 'Step': 324, 'Prediction': 0.23317785370807195}
# {'MAE': MAE: 0.161329, 'Step': 325, 'Prediction': 0.23669283282357187}
# {'MAE': MAE: 0.161, 'Step': 326, 'Prediction': 0.2276233498318396}
# {'MAE': MAE: 0.160642, 'Step': 327, 'Prediction': 0.18269707663431006}
# {'MAE': MAE: 0.160228, 'Step': 328, 'Prediction': 0.18103408853514635}
# {'MAE': MAE: 0.159839, 'Step': 329, 'Prediction': 0.18307633803038603}
# {'MAE': MAE: 0.159513, 'Step': 330, 'Prediction': 0.18522726070911716}
# {'MAE': MAE: 0.159274, 'Step': 331, 'Prediction': 0.1998951202481064}
# {'MAE': MAE: 0.159022, 'Step': 332, 'Prediction': 0.20739421836111674}
# {'MAE': MAE: 0.15871, 'Step': 333, 'Prediction': 0.2101169036622652}
# {'MAE': MAE: 0.158315, 'Step': 334, 'Prediction': 0.20865036839157067}
# {'MAE': MAE: 0.158125, 'Step': 335, 'Prediction': 0.19828331140765276}
# {'MAE': MAE: 0.157883, 'Step': 336, 'Prediction': 0.19368122092403545}
# {'MAE': MAE: 0.157505, 'Step': 337, 'Prediction': 0.18754031099359744}
# {'MAE': MAE: 0.157089, 'Step': 338, 'Prediction': 0.18886223313677278}
# {'MAE': MAE: 0.156737, 'Step': 339, 'Prediction': 0.19164118408898276}
# {'MAE': MAE: 0.156347, 'Step': 340, 'Prediction': 0.19348940602994325}
# {'MAE': MAE: 0.155982, 'Step': 341, 'Prediction': 0.19573378296586946}
# {'MAE': MAE: 0.155554, 'Step': 342, 'Prediction': 0.19681373060917243}
# {'MAE': MAE: 0.155104, 'Step': 343, 'Prediction': 0.22574471923415607}
# {'MAE': MAE: 0.154862, 'Step': 344, 'Prediction': 0.22952111947429266}
# {'MAE': MAE: 0.154759, 'Step': 345, 'Prediction': 0.23292826598975433}
# {'MAE': MAE: 0.154625, 'Step': 346, 'Prediction': 0.23613227957070135}
# {'MAE': MAE: 0.154494, 'Step': 347, 'Prediction': 0.23987696849087012}
# {'MAE': MAE: 0.154358, 'Step': 348, 'Prediction': 0.24372770880063402}
# {'MAE': MAE: 0.154169, 'Step': 349, 'Prediction': 0.24519102408988105}
# {'MAE': MAE: 0.153865, 'Step': 350, 'Prediction': 0.24088115428653287}
# {'MAE': MAE: 0.153475, 'Step': 351, 'Prediction': 0.19353583973751223}
# {'MAE': MAE: 0.153119, 'Step': 352, 'Prediction': 0.190603562072055}
# {'MAE': MAE: 0.152693, 'Step': 353, 'Prediction': 0.1824329864977187}
# {'MAE': MAE: 0.152356, 'Step': 354, 'Prediction': 0.17628421755043142}
# {'MAE': MAE: 0.152033, 'Step': 355, 'Prediction': 0.1738425357406917}
# {'MAE': MAE: 0.151695, 'Step': 356, 'Prediction': 0.17019170404419395}
# {'MAE': MAE: 0.151353, 'Step': 357, 'Prediction': 0.17045206649569744}
# {'MAE': MAE: 0.151035, 'Step': 358, 'Prediction': 0.17154807359004004}
# {'MAE': MAE: 0.150891, 'Step': 359, 'Prediction': 0.16295580040327956}
# {'MAE': MAE: 0.15073, 'Step': 360, 'Prediction': 0.16741717641273873}
# {'MAE': MAE: 0.150438, 'Step': 361, 'Prediction': 0.17324326752979344}
# {'MAE': MAE: 0.150174, 'Step': 362, 'Prediction': 0.17205966504726888}
# {'MAE': MAE: 0.149958, 'Step': 363, 'Prediction': 0.18113485242532967}
# {'MAE': MAE: 0.14979, 'Step': 364, 'Prediction': 0.18418673212602776}
# {'MAE': MAE: 0.14953, 'Step': 365, 'Prediction': 0.1938594074645149}
# {'MAE': MAE: 0.149242, 'Step': 366, 'Prediction': 0.19869963515328307}
# {'MAE': MAE: 0.149029, 'Step': 367, 'Prediction': 0.2153588365339503}
# {'MAE': MAE: 0.148962, 'Step': 368, 'Prediction': 0.21648909375648298}
# {'MAE': MAE: 0.14889, 'Step': 369, 'Prediction': 0.22374987045945294}
# {'MAE': MAE: 0.148787, 'Step': 370, 'Prediction': 0.23599902623536778}
# {'MAE': MAE: 0.148682, 'Step': 371, 'Prediction': 0.24708597519218828}
# {'MAE': MAE: 0.148501, 'Step': 372, 'Prediction': 0.25024442899970006}
# {'MAE': MAE: 0.148294, 'Step': 373, 'Prediction': 0.24343145303937613}
# {'MAE': MAE: 0.147933, 'Step': 374, 'Prediction': 0.2381715450480954}
# {'MAE': MAE: 0.147601, 'Step': 375, 'Prediction': 0.19220680266820683}
# {'MAE': MAE: 0.14723, 'Step': 376, 'Prediction': 0.19395795383001288}
# {'MAE': MAE: 0.146908, 'Step': 377, 'Prediction': 0.19554283588780083}
# {'MAE': MAE: 0.146657, 'Step': 378, 'Prediction': 0.20604132535338912}
# {'MAE': MAE: 0.146498, 'Step': 379, 'Prediction': 0.2067533563078518}
# {'MAE': MAE: 0.146278, 'Step': 380, 'Prediction': 0.20538189838849544}
# {'MAE': MAE: 0.146028, 'Step': 381, 'Prediction': 0.20435829746991113}
# {'MAE': MAE: 0.145732, 'Step': 382, 'Prediction': 0.20675729449996158}
# {'MAE': MAE: 0.145637, 'Step': 383, 'Prediction': 0.19836532278762253}
# {'MAE': MAE: 0.145427, 'Step': 384, 'Prediction': 0.1978215409157065}
# {'MAE': MAE: 0.145131, 'Step': 385, 'Prediction': 0.1944244139511977}
# {'MAE': MAE: 0.144828, 'Step': 386, 'Prediction': 0.19847635126489488}
# {'MAE': MAE: 0.144533, 'Step': 387, 'Prediction': 0.20149172382866815}
# {'MAE': MAE: 0.144239, 'Step': 388, 'Prediction': 0.20462564886827972}
# {'MAE': MAE: 0.143959, 'Step': 389, 'Prediction': 0.2086716735505968}
# {'MAE': MAE: 0.143727, 'Step': 390, 'Prediction': 0.21225961084666722}
# {'MAE': MAE: 0.143385, 'Step': 391, 'Prediction': 0.23871226209337731}
# {'MAE': MAE: 0.143232, 'Step': 392, 'Prediction': 0.243692137821358}
# {'MAE': MAE: 0.143091, 'Step': 393, 'Prediction': 0.2476306286501003}
# {'MAE': MAE: 0.143028, 'Step': 394, 'Prediction': 0.25253676892622834}
# {'MAE': MAE: 0.142981, 'Step': 395, 'Prediction': 0.25694732384280294}
# {'MAE': MAE: 0.142831, 'Step': 396, 'Prediction': 0.26062252393418256}
# {'MAE': MAE: 0.14261, 'Step': 397, 'Prediction': 0.2625612861922485}
# {'MAE': MAE: 0.142297, 'Step': 398, 'Prediction': 0.2642346931015582}
# {'MAE': MAE: 0.142009, 'Step': 399, 'Prediction': 0.21446233754794494}
# {'MAE': MAE: 0.141689, 'Step': 400, 'Prediction': 0.21614708005366173}
# {'MAE': MAE: 0.141435, 'Step': 401, 'Prediction': 0.21729363714258973}
# {'MAE': MAE: 0.141211, 'Step': 402, 'Prediction': 0.21838742170122186}
# {'MAE': MAE: 0.141078, 'Step': 403, 'Prediction': 0.21918018054871036}
# {'MAE': MAE: 0.140929, 'Step': 404, 'Prediction': 0.2194780416361499}
# {'MAE': MAE: 0.140789, 'Step': 405, 'Prediction': 0.22009965703924464}
# {'MAE': MAE: 0.140484, 'Step': 406, 'Prediction': 0.22102525361774814}
# {'MAE': MAE: 0.140236, 'Step': 407, 'Prediction': 0.21014885000532865}
# {'MAE': MAE: 0.139955, 'Step': 408, 'Prediction': 0.1981504130080649}
# {'MAE': MAE: 0.139771, 'Step': 409, 'Prediction': 0.19125987386982063}
# {'MAE': MAE: 0.139588, 'Step': 410, 'Prediction': 0.19217165234619957}
# {'MAE': MAE: 0.139529, 'Step': 411, 'Prediction': 0.19662699410482926}
# {'MAE': MAE: 0.139371, 'Step': 412, 'Prediction': 0.20085262056028746}
# {'MAE': MAE: 0.13922, 'Step': 413, 'Prediction': 0.2153852343755432}
# {'MAE': MAE: 0.139067, 'Step': 414, 'Prediction': 0.22610808842338667}
# {'MAE': MAE: 0.138943, 'Step': 415, 'Prediction': 0.25028086594052384}
# {'MAE': MAE: 0.138956, 'Step': 416, 'Prediction': 0.2502800160874349}
# {'MAE': MAE: 0.139036, 'Step': 417, 'Prediction': 0.25334229381448375}
# {'MAE': MAE: 0.139106, 'Step': 418, 'Prediction': 0.24979731682669346}
# {'MAE': MAE: 0.139069, 'Step': 419, 'Prediction': 0.25337435476380105}
# {'MAE': MAE: 0.138935, 'Step': 420, 'Prediction': 0.2599686011073902}
# {'MAE': MAE: 0.138767, 'Step': 421, 'Prediction': 0.26089999207878617}
# {'MAE': MAE: 0.138531, 'Step': 422, 'Prediction': 0.2619714988598589}
# {'MAE': MAE: 0.138295, 'Step': 423, 'Prediction': 0.2062917191640915}
# {'MAE': MAE: 0.138073, 'Step': 424, 'Prediction': 0.2090527307088503}
# {'MAE': MAE: 0.137813, 'Step': 425, 'Prediction': 0.21004999637991217}
# {'MAE': MAE: 0.137604, 'Step': 426, 'Prediction': 0.2089376999220345}
# {'MAE': MAE: 0.137439, 'Step': 427, 'Prediction': 0.20976891764461372}
# {'MAE': MAE: 0.137257, 'Step': 428, 'Prediction': 0.2078387408117971}
# {'MAE': MAE: 0.137056, 'Step': 429, 'Prediction': 0.20800860904952004}
# {'MAE': MAE: 0.136835, 'Step': 430, 'Prediction': 0.2090574002609613}
# {'MAE': MAE: 0.13654, 'Step': 431, 'Prediction': 0.20001454885142958}
# {'MAE': MAE: 0.136313, 'Step': 432, 'Prediction': 0.20419744046056307}
# {'MAE': MAE: 0.136122, 'Step': 433, 'Prediction': 0.2090480219339083}
# {'MAE': MAE: 0.135937, 'Step': 434, 'Prediction': 0.21479352088199924}
# {'MAE': MAE: 0.135894, 'Step': 435, 'Prediction': 0.22075757714433655}
# {'MAE': MAE: 0.135858, 'Step': 436, 'Prediction': 0.2281661466098237}
# {'MAE': MAE: 0.135715, 'Step': 437, 'Prediction': 0.23329646987195746}
# {'MAE': MAE: 0.13573, 'Step': 438, 'Prediction': 0.23986648923080234}
# {'MAE': MAE: 0.135626, 'Step': 439, 'Prediction': 0.25491238801200145}
# {'MAE': MAE: 0.135591, 'Step': 440, 'Prediction': 0.26099249132518554}
# {'MAE': MAE: 0.135608, 'Step': 441, 'Prediction': 0.2692886432891222}
# {'MAE': MAE: 0.135589, 'Step': 442, 'Prediction': 0.2854279644483795}
# {'MAE': MAE: 0.13551, 'Step': 443, 'Prediction': 0.2916348137749132}
# {'MAE': MAE: 0.135359, 'Step': 444, 'Prediction': 0.29962591924604076}
# {'MAE': MAE: 0.135125, 'Step': 445, 'Prediction': 0.300801481394382}
# {'MAE': MAE: 0.134844, 'Step': 446, 'Prediction': 0.28962890089063836}
# {'MAE': MAE: 0.134575, 'Step': 447, 'Prediction': 0.18278932936595318}
# {'MAE': MAE: 0.134297, 'Step': 448, 'Prediction': 0.18919187947058713}
# {'MAE': MAE: 0.134126, 'Step': 449, 'Prediction': 0.20224183492142256}
# {'MAE': MAE: 0.133956, 'Step': 450, 'Prediction': 0.20648459939283131}
# {'MAE': MAE: 0.133842, 'Step': 451, 'Prediction': 0.2029203287159787}
# {'MAE': MAE: 0.133714, 'Step': 452, 'Prediction': 0.20362520940286968}
# {'MAE': MAE: 0.133544, 'Step': 453, 'Prediction': 0.2052465064329718}
# {'MAE': MAE: 0.133295, 'Step': 454, 'Prediction': 0.21035611382475763}
# {'MAE': MAE: 0.133225, 'Step': 455, 'Prediction': 0.20835128148250065}
# {'MAE': MAE: 0.133055, 'Step': 456, 'Prediction': 0.20914330441811183}
# {'MAE': MAE: 0.132851, 'Step': 457, 'Prediction': 0.20439636719705034}
# {'MAE': MAE: 0.132621, 'Step': 458, 'Prediction': 0.20664070043638028}
# {'MAE': MAE: 0.132349, 'Step': 459, 'Prediction': 0.21007087263087237}
# {'MAE': MAE: 0.132099, 'Step': 460, 'Prediction': 0.212381097936187}
# {'MAE': MAE: 0.131885, 'Step': 461, 'Prediction': 0.19950284396604445}
# {'MAE': MAE: 0.131687, 'Step': 462, 'Prediction': 0.1982959244362914}
# {'MAE': MAE: 0.13156, 'Step': 463, 'Prediction': 0.22138957509063956}
# {'MAE': MAE: 0.131473, 'Step': 464, 'Prediction': 0.22935863428404538}
# {'MAE': MAE: 0.131507, 'Step': 465, 'Prediction': 0.2349074798768898}
# {'MAE': MAE: 0.131569, 'Step': 466, 'Prediction': 0.24595049569566094}
# {'MAE': MAE: 0.131662, 'Step': 467, 'Prediction': 0.2554882295843411}
# {'MAE': MAE: 0.131621, 'Step': 468, 'Prediction': 0.26310916312450705}
# {'MAE': MAE: 0.131492, 'Step': 469, 'Prediction': 0.2727940375192604}
# {'MAE': MAE: 0.131229, 'Step': 470, 'Prediction': 0.27316589826172905}
# {'MAE': MAE: 0.130969, 'Step': 471, 'Prediction': 0.22112166406907316}
# {'MAE': MAE: 0.130705, 'Step': 472, 'Prediction': 0.2166514431644631}
# {'MAE': MAE: 0.130536, 'Step': 473, 'Prediction': 0.21099369906549256}
# {'MAE': MAE: 0.130426, 'Step': 474, 'Prediction': 0.20845229700577805}
# {'MAE': MAE: 0.130349, 'Step': 475, 'Prediction': 0.21148487732798787}
# {'MAE': MAE: 0.130289, 'Step': 476, 'Prediction': 0.22610330168111104}
# {'MAE': MAE: 0.130175, 'Step': 477, 'Prediction': 0.2268568033098932}
# {'MAE': MAE: 0.129929, 'Step': 478, 'Prediction': 0.22589458908010943}
# {'MAE': MAE: 0.129749, 'Step': 479, 'Prediction': 0.2222085495402322}
# {'MAE': MAE: 0.129514, 'Step': 480, 'Prediction': 0.22235575854246378}
# {'MAE': MAE: 0.129312, 'Step': 481, 'Prediction': 0.21606870077414145}
# {'MAE': MAE: 0.129053, 'Step': 482, 'Prediction': 0.2191521134583231}
# {'MAE': MAE: 0.128793, 'Step': 483, 'Prediction': 0.22055865592575172}
# {'MAE': MAE: 0.128583, 'Step': 484, 'Prediction': 0.21765112317235755}
# {'MAE': MAE: 0.128337, 'Step': 485, 'Prediction': 0.22306343134684467}
# {'MAE': MAE: 0.128082, 'Step': 486, 'Prediction': 0.2263509248619292}
# {'MAE': MAE: 0.127868, 'Step': 487, 'Prediction': 0.24887838751219493}
# {'MAE': MAE: 0.127751, 'Step': 488, 'Prediction': 0.2535629621154836}
# {'MAE': MAE: 0.127771, 'Step': 489, 'Prediction': 0.259515125105591}
# {'MAE': MAE: 0.127806, 'Step': 490, 'Prediction': 0.2629809771704918}
# {'MAE': MAE: 0.12778, 'Step': 491, 'Prediction': 0.2733313987478107}
# {'MAE': MAE: 0.127752, 'Step': 492, 'Prediction': 0.27739594611347873}
# {'MAE': MAE: 0.127706, 'Step': 493, 'Prediction': 0.26842987079251096}
# {'MAE': MAE: 0.127491, 'Step': 494, 'Prediction': 0.27038179759180314}
# {'MAE': MAE: 0.127272, 'Step': 495, 'Prediction': 0.2044947282161208}
# {'MAE': MAE: 0.127021, 'Step': 496, 'Prediction': 0.2076984192215063}
# {'MAE': MAE: 0.126814, 'Step': 497, 'Prediction': 0.20973422096080319}
# {'MAE': MAE: 0.12668, 'Step': 498, 'Prediction': 0.21080852344426065}
# {'MAE': MAE: 0.126577, 'Step': 499, 'Prediction': 0.21131992729402002}
# {'MAE': MAE: 0.126487, 'Step': 500, 'Prediction': 0.21239531109894216}
# {'MAE': MAE: 0.126343, 'Step': 501, 'Prediction': 0.21373684061554726}
# {'MAE': MAE: 0.126131, 'Step': 502, 'Prediction': 0.2175340558475946}
# {'MAE': MAE: 0.126025, 'Step': 503, 'Prediction': 0.21265114787704956}
# {'MAE': MAE: 0.125892, 'Step': 504, 'Prediction': 0.21725927787227614}
# {'MAE': MAE: 0.12571, 'Step': 505, 'Prediction': 0.21112374456859315}
# {'MAE': MAE: 0.125549, 'Step': 506, 'Prediction': 0.21060181708970807}
# {'MAE': MAE: 0.12536, 'Step': 507, 'Prediction': 0.21450437095487232}
# {'MAE': MAE: 0.125141, 'Step': 508, 'Prediction': 0.2228910643620256}
# {'MAE': MAE: 0.124923, 'Step': 509, 'Prediction': 0.2281329346454632}
# {'MAE': MAE: 0.124776, 'Step': 510, 'Prediction': 0.22125821083330371}
# {'MAE': MAE: 0.124598, 'Step': 511, 'Prediction': 0.2446365780710187}
# {'MAE': MAE: 0.12456, 'Step': 512, 'Prediction': 0.24851058643178897}
# {'MAE': MAE: 0.124575, 'Step': 513, 'Prediction': 0.2518766008894195}
# {'MAE': MAE: 0.124659, 'Step': 514, 'Prediction': 0.25753759025209555}
# {'MAE': MAE: 0.124713, 'Step': 515, 'Prediction': 0.2634910309476587}
# {'MAE': MAE: 0.124755, 'Step': 516, 'Prediction': 0.2696200111621208}
# {'MAE': MAE: 0.124614, 'Step': 517, 'Prediction': 0.2771727139910443}
# {'MAE': MAE: 0.124375, 'Step': 518, 'Prediction': 0.28428213501253863}
# {'MAE': MAE: 0.124179, 'Step': 519, 'Prediction': 0.22251821602578126}
# {'MAE': MAE: 0.123983, 'Step': 520, 'Prediction': 0.21227427782917022}
# {'MAE': MAE: 0.123812, 'Step': 521, 'Prediction': 0.2104755793633386}
# {'MAE': MAE: 0.123669, 'Step': 522, 'Prediction': 0.2115804912638828}
# {'MAE': MAE: 0.123589, 'Step': 523, 'Prediction': 0.21166496851009955}
# {'MAE': MAE: 0.123513, 'Step': 524, 'Prediction': 0.21239020362256322}
# {'MAE': MAE: 0.123368, 'Step': 525, 'Prediction': 0.21178633884256312}
# {'MAE': MAE: 0.123159, 'Step': 526, 'Prediction': 0.22634933263023518}
# {'MAE': MAE: 0.123075, 'Step': 527, 'Prediction': 0.23602810094699}
# {'MAE': MAE: 0.12291, 'Step': 528, 'Prediction': 0.24232591085652722}
# {'MAE': MAE: 0.122701, 'Step': 529, 'Prediction': 0.23254955036950412}
# {'MAE': MAE: 0.122506, 'Step': 530, 'Prediction': 0.228704673058563}
# {'MAE': MAE: 0.122305, 'Step': 531, 'Prediction': 0.227636919281653}
# {'MAE': MAE: 0.122141, 'Step': 532, 'Prediction': 0.24024127900714043}
# {'MAE': MAE: 0.121944, 'Step': 533, 'Prediction': 0.24983146141534618}
# {'MAE': MAE: 0.121749, 'Step': 534, 'Prediction': 0.2513446250193665}
# {'MAE': MAE: 0.12158, 'Step': 535, 'Prediction': 0.2748392521936985}
# {'MAE': MAE: 0.121513, 'Step': 536, 'Prediction': 0.2683725970460505}
# {'MAE': MAE: 0.121467, 'Step': 537, 'Prediction': 0.26273449812842903}
# {'MAE': MAE: 0.121497, 'Step': 538, 'Prediction': 0.2693311583726704}
# {'MAE': MAE: 0.121476, 'Step': 539, 'Prediction': 0.2751986212722286}
# {'MAE': MAE: 0.121435, 'Step': 540, 'Prediction': 0.28481019975649124}
# {'MAE': MAE: 0.12129, 'Step': 541, 'Prediction': 0.29676189581333057}
# {'MAE': MAE: 0.121101, 'Step': 542, 'Prediction': 0.3040263275843661}
# {'MAE': MAE: 0.120902, 'Step': 543, 'Prediction': 0.23342967057922642}
# {'MAE': MAE: 0.120727, 'Step': 544, 'Prediction': 0.23705039382875218}
# {'MAE': MAE: 0.120633, 'Step': 545, 'Prediction': 0.23647599274959746}
# {'MAE': MAE: 0.120549, 'Step': 546, 'Prediction': 0.23536344818568522}
# {'MAE': MAE: 0.120495, 'Step': 547, 'Prediction': 0.2321283570383668}
# {'MAE': MAE: 0.120425, 'Step': 548, 'Prediction': 0.22980909325380464}
# {'MAE': MAE: 0.120343, 'Step': 549, 'Prediction': 0.23366489221101894}
# {'MAE': MAE: 0.120129, 'Step': 550, 'Prediction': 0.23441415255928622}
# {'MAE': MAE: 0.120058, 'Step': 551, 'Prediction': 0.24663698059858755}
# {'MAE': MAE: 0.119945, 'Step': 552, 'Prediction': 0.24491533239539257}
# {'MAE': MAE: 0.119823, 'Step': 553, 'Prediction': 0.24611463340913156}
# {'MAE': MAE: 0.119637, 'Step': 554, 'Prediction': 0.2498214032333686}
# {'MAE': MAE: 0.119448, 'Step': 555, 'Prediction': 0.2543585490917507}
# {'MAE': MAE: 0.119295, 'Step': 556, 'Prediction': 0.2469371601967099}
# {'MAE': MAE: 0.119145, 'Step': 557, 'Prediction': 0.25098654294867223}
# {'MAE': MAE: 0.119019, 'Step': 558, 'Prediction': 0.25649517732364324}
# {'MAE': MAE: 0.118866, 'Step': 559, 'Prediction': 0.27812797123611394}
# {'MAE': MAE: 0.118846, 'Step': 560, 'Prediction': 0.2723925322577281}
# {'MAE': MAE: 0.11892, 'Step': 561, 'Prediction': 0.28182554747601035}
# {'MAE': MAE: 0.118968, 'Step': 562, 'Prediction': 0.28916934120340176}
# {'MAE': MAE: 0.118926, 'Step': 563, 'Prediction': 0.2883170439816109}
# {'MAE': MAE: 0.118869, 'Step': 564, 'Prediction': 0.28600168263624254}
# {'MAE': MAE: 0.118816, 'Step': 565, 'Prediction': 0.2870862145100669}
# {'MAE': MAE: 0.118702, 'Step': 566, 'Prediction': 0.2878791112666368}
# {'MAE': MAE: 0.118583, 'Step': 567, 'Prediction': 0.21054261168985955}
# {'MAE': MAE: 0.118381, 'Step': 568, 'Prediction': 0.22302814830880488}
# {'MAE': MAE: 0.118256, 'Step': 569, 'Prediction': 0.23684640244773708}
# {'MAE': MAE: 0.118143, 'Step': 570, 'Prediction': 0.23791891065405904}
# {'MAE': MAE: 0.118071, 'Step': 571, 'Prediction': 0.23679935614614753}
# {'MAE': MAE: 0.117999, 'Step': 572, 'Prediction': 0.23654970992130056}
# {'MAE': MAE: 0.117926, 'Step': 573, 'Prediction': 0.23559034715262175}
# {'MAE': MAE: 0.1178, 'Step': 574, 'Prediction': 0.23464156217033286}
# {'MAE': MAE: 0.117606, 'Step': 575, 'Prediction': 0.23742326794590285}
# {'MAE': MAE: 0.117472, 'Step': 576, 'Prediction': 0.2360763628499357}
# {'MAE': MAE: 0.117377, 'Step': 577, 'Prediction': 0.23135640927481707}
# {'MAE': MAE: 0.117345, 'Step': 578, 'Prediction': 0.23547452144587055}
# {'MAE': MAE: 0.117347, 'Step': 579, 'Prediction': 0.2446506198948945}
# {'MAE': MAE: 0.117325, 'Step': 580, 'Prediction': 0.25069247998772665}
# {'MAE': MAE: 0.117175, 'Step': 581, 'Prediction': 0.25788251584254335}
# {'MAE': MAE: 0.117061, 'Step': 582, 'Prediction': 0.2610477289958552}
# {'MAE': MAE: 0.116915, 'Step': 583, 'Prediction': 0.2829920988030817}
# {'MAE': MAE: 0.116895, 'Step': 584, 'Prediction': 0.2873896269071055}
# {'MAE': MAE: 0.116919, 'Step': 585, 'Prediction': 0.29955909052633617}
# {'MAE': MAE: 0.116945, 'Step': 586, 'Prediction': 0.30656134980582794}
# {'MAE': MAE: 0.116916, 'Step': 587, 'Prediction': 0.31153488878553004}
# {'MAE': MAE: 0.116804, 'Step': 588, 'Prediction': 0.3161604520751614}
# {'MAE': MAE: 0.116648, 'Step': 589, 'Prediction': 0.32167150453392623}
# {'MAE': MAE: 0.11647, 'Step': 590, 'Prediction': 0.3253946831467168}
# {'MAE': MAE: 0.116283, 'Step': 591, 'Prediction': 0.24364772210799146}
# {'MAE': MAE: 0.1161, 'Step': 592, 'Prediction': 0.24828595142461307}
# {'MAE': MAE: 0.115993, 'Step': 593, 'Prediction': 0.25069188749299653}
# {'MAE': MAE: 0.115951, 'Step': 594, 'Prediction': 0.25254767813771173}
# {'MAE': MAE: 0.115938, 'Step': 595, 'Prediction': 0.25387704020992125}
# {'MAE': MAE: 0.115915, 'Step': 596, 'Prediction': 0.25565696888953937}
# {'MAE': MAE: 0.115887, 'Step': 597, 'Prediction': 0.257586820652226}
# {'MAE': MAE: 0.115824, 'Step': 598, 'Prediction': 0.25977086457581516}
# {'MAE': MAE: 0.115738, 'Step': 599, 'Prediction': 0.26143506185776727}
# {'MAE': MAE: 0.115564, 'Step': 600, 'Prediction': 0.25791249054246645}
# {'MAE': MAE: 0.115492, 'Step': 601, 'Prediction': 0.2534168772487542}
# {'MAE': MAE: 0.115421, 'Step': 602, 'Prediction': 0.2578687726850356}
# {'MAE': MAE: 0.115392, 'Step': 603, 'Prediction': 0.2640912250538846}
# {'MAE': MAE: 0.115391, 'Step': 604, 'Prediction': 0.27025819246745764}
# {'MAE': MAE: 0.11535, 'Step': 605, 'Prediction': 0.2754579172646583}
# {'MAE': MAE: 0.115338, 'Step': 606, 'Prediction': 0.2829096452815632}
# {'MAE': MAE: 0.115322, 'Step': 607, 'Prediction': 0.30114899996823863}
# {'MAE': MAE: 0.115381, 'Step': 608, 'Prediction': 0.30587799141644145}
# {'MAE': MAE: 0.115459, 'Step': 609, 'Prediction': 0.3114179006936394}
# {'MAE': MAE: 0.115489, 'Step': 610, 'Prediction': 0.3163859730879507}
# {'MAE': MAE: 0.115473, 'Step': 611, 'Prediction': 0.31977527111839343}
# {'MAE': MAE: 0.115444, 'Step': 612, 'Prediction': 0.32070304860550464}
# {'MAE': MAE: 0.115356, 'Step': 613, 'Prediction': 0.3245990768949928}
# {'MAE': MAE: 0.115188, 'Step': 614, 'Prediction': 0.3276958286626416}
# {'MAE': MAE: 0.115053, 'Step': 615, 'Prediction': 0.20409413425502113}
# {'MAE': MAE: 0.114928, 'Step': 616, 'Prediction': 0.2098129751640323}
# {'MAE': MAE: 0.114755, 'Step': 617, 'Prediction': 0.2116772164479133}
# {'MAE': MAE: 0.114606, 'Step': 618, 'Prediction': 0.20631748079088874}
# {'MAE': MAE: 0.11451, 'Step': 619, 'Prediction': 0.21556005986064658}
# {'MAE': MAE: 0.114416, 'Step': 620, 'Prediction': 0.2132489544163455}
# {'MAE': MAE: 0.1143, 'Step': 621, 'Prediction': 0.2063126037798486}
# {'MAE': MAE: 0.114146, 'Step': 622, 'Prediction': 0.2073013058168625}
# {'MAE': MAE: 0.114071, 'Step': 623, 'Prediction': 0.2160506250987373}
# {'MAE': MAE: 0.114039, 'Step': 624, 'Prediction': 0.21741570963444812}
# {'MAE': MAE: 0.113962, 'Step': 625, 'Prediction': 0.22328047403574364}
# {'MAE': MAE: 0.113929, 'Step': 626, 'Prediction': 0.22767980630735368}
# {'MAE': MAE: 0.11384, 'Step': 627, 'Prediction': 0.23847694264988137}
# {'MAE': MAE: 0.113773, 'Step': 628, 'Prediction': 0.2474553630312702}
# {'MAE': MAE: 0.113735, 'Step': 629, 'Prediction': 0.2544777116095297}
# {'MAE': MAE: 0.113698, 'Step': 630, 'Prediction': 0.2613330525060574}
# {'MAE': MAE: 0.11364, 'Step': 631, 'Prediction': 0.2864330356460999}
# {'MAE': MAE: 0.1136, 'Step': 632, 'Prediction': 0.3000160405956105}
# {'MAE': MAE: 0.113571, 'Step': 633, 'Prediction': 0.3042361527485842}
# {'MAE': MAE: 0.113633, 'Step': 634, 'Prediction': 0.28158467337037035}
# {'MAE': MAE: 0.113677, 'Step': 635, 'Prediction': 0.2867445894088925}
# {'MAE': MAE: 0.113703, 'Step': 636, 'Prediction': 0.2916389062540166}
# {'MAE': MAE: 0.113671, 'Step': 637, 'Prediction': 0.296507601107614}
# {'MAE': MAE: 0.113529, 'Step': 638, 'Prediction': 0.29689935257582967}
# {'MAE': MAE: 0.113428, 'Step': 639, 'Prediction': 0.2040700985565927}
# {'MAE': MAE: 0.113309, 'Step': 640, 'Prediction': 0.21479320338115993}
# {'MAE': MAE: 0.113167, 'Step': 641, 'Prediction': 0.22250433401874953}
# {'MAE': MAE: 0.113043, 'Step': 642, 'Prediction': 0.21863031540233718}
# {'MAE': MAE: 0.112958, 'Step': 643, 'Prediction': 0.2160799409978707}
# {'MAE': MAE: 0.112884, 'Step': 644, 'Prediction': 0.22310705882284274}
# {'MAE': MAE: 0.112792, 'Step': 645, 'Prediction': 0.21849395884098421}
# {'MAE': MAE: 0.112618, 'Step': 646, 'Prediction': 0.21310919345535262}
# {'MAE': MAE: 0.112515, 'Step': 647, 'Prediction': 0.21814244194944526}
# {'MAE': MAE: 0.112423, 'Step': 648, 'Prediction': 0.2220546588718797}
# {'MAE': MAE: 0.112319, 'Step': 649, 'Prediction': 0.21754380600494674}
# {'MAE': MAE: 0.112174, 'Step': 650, 'Prediction': 0.2207144580613662}
# {'MAE': MAE: 0.112051, 'Step': 651, 'Prediction': 0.22473261960739777}
# {'MAE': MAE: 0.111913, 'Step': 652, 'Prediction': 0.23667937675405437}
# {'MAE': MAE: 0.1118, 'Step': 653, 'Prediction': 0.2454015613141774}
# {'MAE': MAE: 0.111644, 'Step': 654, 'Prediction': 0.2499780956283965}
# {'MAE': MAE: 0.111531, 'Step': 655, 'Prediction': 0.2522655296573673}
# {'MAE': MAE: 0.111472, 'Step': 656, 'Prediction': 0.26079959371470274}
# {'MAE': MAE: 0.111463, 'Step': 657, 'Prediction': 0.2696417006196554}
# {'MAE': MAE: 0.111494, 'Step': 658, 'Prediction': 0.27635645169704376}
# {'MAE': MAE: 0.111501, 'Step': 659, 'Prediction': 0.2848964276822915}
# {'MAE': MAE: 0.111451, 'Step': 660, 'Prediction': 0.29456494140651057}
# {'MAE': MAE: 0.11134, 'Step': 661, 'Prediction': 0.3035707141687395}
# {'MAE': MAE: 0.111176, 'Step': 662, 'Prediction': 0.3159676120345258}
# {'MAE': MAE: 0.111008, 'Step': 663, 'Prediction': 0.23095932571724906}
# {'MAE': MAE: 0.110869, 'Step': 664, 'Prediction': 0.23697049168759562}
# {'MAE': MAE: 0.110774, 'Step': 665, 'Prediction': 0.2382550548582409}
# {'MAE': MAE: 0.110719, 'Step': 666, 'Prediction': 0.24092058432262067}
# {'MAE': MAE: 0.110696, 'Step': 667, 'Prediction': 0.24317771326630466}
# {'MAE': MAE: 0.110686, 'Step': 668, 'Prediction': 0.24532951251473048}
# {'MAE': MAE: 0.110652, 'Step': 669, 'Prediction': 0.24837900393067935}
# {'MAE': MAE: 0.110568, 'Step': 670, 'Prediction': 0.2528172632294371}
# {'MAE': MAE: 0.110425, 'Step': 671, 'Prediction': 0.2573526578645717}
# {'MAE': MAE: 0.110301, 'Step': 672, 'Prediction': 0.25285988129428527}
# {'MAE': MAE: 0.110148, 'Step': 673, 'Prediction': 0.2617710637903853}
# {'MAE': MAE: 0.109985, 'Step': 674, 'Prediction': 0.2686802984891747}
# {'MAE': MAE: 0.109837, 'Step': 675, 'Prediction': 0.2721553156899816}
# {'MAE': MAE: 0.109708, 'Step': 676, 'Prediction': 0.276155285162146}
# {'MAE': MAE: 0.109551, 'Step': 677, 'Prediction': 0.2674319227964414}
# {'MAE': MAE: 0.1094, 'Step': 678, 'Prediction': 0.2705707208562765}
# {'MAE': MAE: 0.109256, 'Step': 679, 'Prediction': 0.28752546381523236}
# {'MAE': MAE: 0.10914, 'Step': 680, 'Prediction': 0.29366884781901226}
# {'MAE': MAE: 0.109082, 'Step': 681, 'Prediction': 0.2897401743781544}
# {'MAE': MAE: 0.109049, 'Step': 682, 'Prediction': 0.29538931123215806}
# {'MAE': MAE: 0.108964, 'Step': 683, 'Prediction': 0.299334468238479}
# {'MAE': MAE: 0.108836, 'Step': 684, 'Prediction': 0.3055524004672192}
# {'MAE': MAE: 0.108694, 'Step': 685, 'Prediction': 0.3117269491356393}
# {'MAE': MAE: 0.108597, 'Step': 686, 'Prediction': 0.3189013123310557}
# {'MAE': MAE: 0.10844, 'Step': 687, 'Prediction': 0.2188456037779221}
# {'MAE': MAE: 0.108298, 'Step': 688, 'Prediction': 0.22495085827739192}
# {'MAE': MAE: 0.108196, 'Step': 689, 'Prediction': 0.22942615497531055}
# {'MAE': MAE: 0.108134, 'Step': 690, 'Prediction': 0.22648448839199603}
# {'MAE': MAE: 0.108113, 'Step': 691, 'Prediction': 0.22688711004192452}
# {'MAE': MAE: 0.108099, 'Step': 692, 'Prediction': 0.2289273713214518}
# {'MAE': MAE: 0.108067, 'Step': 693, 'Prediction': 0.23473230842689144}
# {'MAE': MAE: 0.107996, 'Step': 694, 'Prediction': 0.23998001881049918}
# {'MAE': MAE: 0.107896, 'Step': 695, 'Prediction': 0.2485560506166081}
# {'MAE': MAE: 0.107743, 'Step': 696, 'Prediction': 0.2530205214063693}
# {'MAE': MAE: 0.107625, 'Step': 697, 'Prediction': 0.26330732068115403}
# {'MAE': MAE: 0.107514, 'Step': 698, 'Prediction': 0.2735159224988989}
# {'MAE': MAE: 0.107382, 'Step': 699, 'Prediction': 0.2771812843914304}
# {'MAE': MAE: 0.10728, 'Step': 700, 'Prediction': 0.27899261813019643}
# {'MAE': MAE: 0.107185, 'Step': 701, 'Prediction': 0.27826356052695}
# {'MAE': MAE: 0.107068, 'Step': 702, 'Prediction': 0.28453281553739096}
# {'MAE': MAE: 0.106965, 'Step': 703, 'Prediction': 0.2958298085846498}
# {'MAE': MAE: 0.106819, 'Step': 704, 'Prediction': 0.30221101930589434}
# {'MAE': MAE: 0.106733, 'Step': 705, 'Prediction': 0.309117660438619}
# {'MAE': MAE: 0.106681, 'Step': 706, 'Prediction': 0.317941992416092}
# {'MAE': MAE: 0.106601, 'Step': 707, 'Prediction': 0.3263281734342234}
# {'MAE': MAE: 0.106486, 'Step': 708, 'Prediction': 0.33264773523963515}
# {'MAE': MAE: 0.106356, 'Step': 709, 'Prediction': 0.33664354155964304}
# {'MAE': MAE: 0.106307, 'Step': 710, 'Prediction': 0.3397317316853595}
# {'MAE': MAE: 0.106165, 'Step': 711, 'Prediction': 0.2362275782069394}
# {'MAE': MAE: 0.106019, 'Step': 712, 'Prediction': 0.2399258302195692}
# {'MAE': MAE: 0.105947, 'Step': 713, 'Prediction': 0.24295985944849544}
# {'MAE': MAE: 0.105923, 'Step': 714, 'Prediction': 0.2456520762710736}
# {'MAE': MAE: 0.105924, 'Step': 715, 'Prediction': 0.24795277495640222}
# {'MAE': MAE: 0.105926, 'Step': 716, 'Prediction': 0.2505303540231213}
# {'MAE': MAE: 0.105932, 'Step': 717, 'Prediction': 0.25327798548565156}
# {'MAE': MAE: 0.105862, 'Step': 718, 'Prediction': 0.2580981282241256}
# {'MAE': MAE: 0.105796, 'Step': 719, 'Prediction': 0.26500854417588815}
# ...
# {'MAE': MAE: 0.035711, 'Step': 19664, 'Prediction': 0.285752073212442}
# {'MAE': MAE: 0.03571, 'Step': 19665, 'Prediction': 0.304332456411201}
# {'MAE': MAE: 0.035711, 'Step': 19666, 'Prediction': 0.3110290301502607}
# {'MAE': MAE: 0.035711, 'Step': 19667, 'Prediction': 0.3202515579209989}
# {'MAE': MAE: 0.035709, 'Step': 19668, 'Prediction': 0.32918341635037496}
# {'MAE': MAE: 0.03571, 'Step': 19669, 'Prediction': 0.3376917434701506}
# {'MAE': MAE: 0.035713, 'Step': 19670, 'Prediction': 0.3442346721916688}
# {'MAE': MAE: 0.035715, 'Step': 19671, 'Prediction': 0.14244036672086982}
# {'MAE': MAE: 0.035715, 'Step': 19672, 'Prediction': 0.15116209354204674}
# {'MAE': MAE: 0.035714, 'Step': 19673, 'Prediction': 0.16088355657884928}
# {'MAE': MAE: 0.035714, 'Step': 19674, 'Prediction': 0.16977725125306792}
# {'MAE': MAE: 0.035716, 'Step': 19675, 'Prediction': 0.1776592843922862}
# {'MAE': MAE: 0.035717, 'Step': 19676, 'Prediction': 0.18612525262666735}
# {'MAE': MAE: 0.035718, 'Step': 19677, 'Prediction': 0.19434672079761556}
# {'MAE': MAE: 0.035718, 'Step': 19678, 'Prediction': 0.2038374048557104}
# {'MAE': MAE: 0.035716, 'Step': 19679, 'Prediction': 0.22043075715333257}
# {'MAE': MAE: 0.035714, 'Step': 19680, 'Prediction': 0.2291302266971403}
# {'MAE': MAE: 0.035713, 'Step': 19681, 'Prediction': 0.23711394559750937}
# {'MAE': MAE: 0.035712, 'Step': 19682, 'Prediction': 0.24519874946713485}
# {'MAE': MAE: 0.035711, 'Step': 19683, 'Prediction': 0.2527095012147728}
# {'MAE': MAE: 0.035711, 'Step': 19684, 'Prediction': 0.26238615920984215}
# {'MAE': MAE: 0.035711, 'Step': 19685, 'Prediction': 0.26030790699375844}
# {'MAE': MAE: 0.035712, 'Step': 19686, 'Prediction': 0.26190136481139265}
# {'MAE': MAE: 0.035713, 'Step': 19687, 'Prediction': 0.2685378998734809}
# {'MAE': MAE: 0.035712, 'Step': 19688, 'Prediction': 0.2812021591441199}
# {'MAE': MAE: 0.035712, 'Step': 19689, 'Prediction': 0.3064141079356444}
# {'MAE': MAE: 0.035712, 'Step': 19690, 'Prediction': 0.31928323682654525}
# {'MAE': MAE: 0.035711, 'Step': 19691, 'Prediction': 0.3289831330315084}
# {'MAE': MAE: 0.035709, 'Step': 19692, 'Prediction': 0.3351935614452129}
# {'MAE': MAE: 0.035709, 'Step': 19693, 'Prediction': 0.3428125503845135}
# {'MAE': MAE: 0.035712, 'Step': 19694, 'Prediction': 0.34953416388375647}
# {'MAE': MAE: 0.035715, 'Step': 19695, 'Prediction': 0.14837661236728364}
# {'MAE': MAE: 0.035714, 'Step': 19696, 'Prediction': 0.1577971977837333}
# {'MAE': MAE: 0.035713, 'Step': 19697, 'Prediction': 0.16772324960089077}
# {'MAE': MAE: 0.035714, 'Step': 19698, 'Prediction': 0.17589966976841037}
# {'MAE': MAE: 0.035716, 'Step': 19699, 'Prediction': 0.18599703506111714}
# {'MAE': MAE: 0.035718, 'Step': 19700, 'Prediction': 0.19494968535302662}
# {'MAE': MAE: 0.035719, 'Step': 19701, 'Prediction': 0.20307329143976152}
# {'MAE': MAE: 0.035719, 'Step': 19702, 'Prediction': 0.2117452769775115}
# {'MAE': MAE: 0.035717, 'Step': 19703, 'Prediction': 0.21754896424104378}
# {'MAE': MAE: 0.035716, 'Step': 19704, 'Prediction': 0.2120235095570048}
# {'MAE': MAE: 0.035715, 'Step': 19705, 'Prediction': 0.22172016702353503}
# {'MAE': MAE: 0.035713, 'Step': 19706, 'Prediction': 0.22991957333811536}
# {'MAE': MAE: 0.035713, 'Step': 19707, 'Prediction': 0.23646973720769598}
# {'MAE': MAE: 0.035712, 'Step': 19708, 'Prediction': 0.24611349171888472}
# {'MAE': MAE: 0.035712, 'Step': 19709, 'Prediction': 0.2551571829263893}
# {'MAE': MAE: 0.035714, 'Step': 19710, 'Prediction': 0.2651980410640634}
# {'MAE': MAE: 0.035715, 'Step': 19711, 'Prediction': 0.2724607385240082}
# {'MAE': MAE: 0.035715, 'Step': 19712, 'Prediction': 0.28154926815962567}
# {'MAE': MAE: 0.035714, 'Step': 19713, 'Prediction': 0.3090392268948262}
# {'MAE': MAE: 0.035714, 'Step': 19714, 'Prediction': 0.3194510472027655}
# {'MAE': MAE: 0.035713, 'Step': 19715, 'Prediction': 0.32587400286550067}
# {'MAE': MAE: 0.035712, 'Step': 19716, 'Prediction': 0.33578515388322916}
# {'MAE': MAE: 0.035713, 'Step': 19717, 'Prediction': 0.3442360279432774}
# {'MAE': MAE: 0.035716, 'Step': 19718, 'Prediction': 0.3501411094771774}
# {'MAE': MAE: 0.035718, 'Step': 19719, 'Prediction': 0.15238683591426272}
# {'MAE': MAE: 0.035717, 'Step': 19720, 'Prediction': 0.16342279593154768}
# {'MAE': MAE: 0.035717, 'Step': 19721, 'Prediction': 0.17360893415438816}
# {'MAE': MAE: 0.035717, 'Step': 19722, 'Prediction': 0.18337447847241886}
# {'MAE': MAE: 0.035719, 'Step': 19723, 'Prediction': 0.19037744497814502}
# {'MAE': MAE: 0.035721, 'Step': 19724, 'Prediction': 0.1973954736862456}
# {'MAE': MAE: 0.035723, 'Step': 19725, 'Prediction': 0.20487412797001076}
# {'MAE': MAE: 0.035724, 'Step': 19726, 'Prediction': 0.2123514841824158}
# {'MAE': MAE: 0.035723, 'Step': 19727, 'Prediction': 0.2174660352650891}
# {'MAE': MAE: 0.035722, 'Step': 19728, 'Prediction': 0.21362400996560701}
# {'MAE': MAE: 0.035721, 'Step': 19729, 'Prediction': 0.2238910067444627}
# {'MAE': MAE: 0.03572, 'Step': 19730, 'Prediction': 0.23075499729337393}
# {'MAE': MAE: 0.035718, 'Step': 19731, 'Prediction': 0.23897443817991518}
# {'MAE': MAE: 0.035716, 'Step': 19732, 'Prediction': 0.24667524719007666}
# {'MAE': MAE: 0.035715, 'Step': 19733, 'Prediction': 0.25768467512211723}
# {'MAE': MAE: 0.035715, 'Step': 19734, 'Prediction': 0.26619750717932966}
# {'MAE': MAE: 0.035716, 'Step': 19735, 'Prediction': 0.274356415315252}
# {'MAE': MAE: 0.035715, 'Step': 19736, 'Prediction': 0.2891632987706298}
# {'MAE': MAE: 0.035714, 'Step': 19737, 'Prediction': 0.30982595411453334}
# {'MAE': MAE: 0.035714, 'Step': 19738, 'Prediction': 0.3217549268851439}
# {'MAE': MAE: 0.035713, 'Step': 19739, 'Prediction': 0.33176283956234287}
# {'MAE': MAE: 0.035713, 'Step': 19740, 'Prediction': 0.3387461144863217}
# {'MAE': MAE: 0.035713, 'Step': 19741, 'Prediction': 0.3447842551962442}
# {'MAE': MAE: 0.035716, 'Step': 19742, 'Prediction': 0.3525409142924214}
# {'MAE': MAE: 0.035719, 'Step': 19743, 'Prediction': 0.14960201662760142}
# {'MAE': MAE: 0.035719, 'Step': 19744, 'Prediction': 0.15903403835091162}
# {'MAE': MAE: 0.035718, 'Step': 19745, 'Prediction': 0.16735066981737678}
# {'MAE': MAE: 0.035718, 'Step': 19746, 'Prediction': 0.17543348974519862}
# {'MAE': MAE: 0.03572, 'Step': 19747, 'Prediction': 0.182990584572439}
# {'MAE': MAE: 0.035722, 'Step': 19748, 'Prediction': 0.19043485516308248}
# {'MAE': MAE: 0.035723, 'Step': 19749, 'Prediction': 0.19802737723309677}
# {'MAE': MAE: 0.035725, 'Step': 19750, 'Prediction': 0.21301411364933404}
# {'MAE': MAE: 0.035725, 'Step': 19751, 'Prediction': 0.22127335333785197}
# {'MAE': MAE: 0.035725, 'Step': 19752, 'Prediction': 0.20931180267332739}
# {'MAE': MAE: 0.035724, 'Step': 19753, 'Prediction': 0.24084079720552448}
# {'MAE': MAE: 0.035724, 'Step': 19754, 'Prediction': 0.22981576033326953}
# {'MAE': MAE: 0.035724, 'Step': 19755, 'Prediction': 0.23877694090586032}
# {'MAE': MAE: 0.035724, 'Step': 19756, 'Prediction': 0.24860175869186246}
# {'MAE': MAE: 0.035723, 'Step': 19757, 'Prediction': 0.2682083997769749}
# {'MAE': MAE: 0.035721, 'Step': 19758, 'Prediction': 0.2831340177636094}
# {'MAE': MAE: 0.03572, 'Step': 19759, 'Prediction': 0.2761091732763997}
# {'MAE': MAE: 0.035718, 'Step': 19760, 'Prediction': 0.3003358287114149}
# {'MAE': MAE: 0.035719, 'Step': 19761, 'Prediction': 0.3096327195132322}
# {'MAE': MAE: 0.035721, 'Step': 19762, 'Prediction': 0.32194440218882103}
# {'MAE': MAE: 0.035721, 'Step': 19763, 'Prediction': 0.332388122987872}
# {'MAE': MAE: 0.035719, 'Step': 19764, 'Prediction': 0.34178035425099923}
# {'MAE': MAE: 0.03572, 'Step': 19765, 'Prediction': 0.3496205423050495}
# {'MAE': MAE: 0.035724, 'Step': 19766, 'Prediction': 0.3547995416037598}
# {'MAE': MAE: 0.035726, 'Step': 19767, 'Prediction': 0.13215289274356512}
# {'MAE': MAE: 0.035726, 'Step': 19768, 'Prediction': 0.14258167848927736}
# {'MAE': MAE: 0.035725, 'Step': 19769, 'Prediction': 0.1514906594873125}
# {'MAE': MAE: 0.035725, 'Step': 19770, 'Prediction': 0.15962551515648934}
# {'MAE': MAE: 0.035726, 'Step': 19771, 'Prediction': 0.16722606352909333}
# {'MAE': MAE: 0.035727, 'Step': 19772, 'Prediction': 0.1746411030980386}
# {'MAE': MAE: 0.035727, 'Step': 19773, 'Prediction': 0.18271447308798938}
# {'MAE': MAE: 0.035725, 'Step': 19774, 'Prediction': 0.19946434522273213}
# {'MAE': MAE: 0.035725, 'Step': 19775, 'Prediction': 0.20562545888028272}
# {'MAE': MAE: 0.035725, 'Step': 19776, 'Prediction': 0.19891056181206143}
# {'MAE': MAE: 0.035723, 'Step': 19777, 'Prediction': 0.20650424928335262}
# {'MAE': MAE: 0.035722, 'Step': 19778, 'Prediction': 0.213489046172447}
# {'MAE': MAE: 0.035721, 'Step': 19779, 'Prediction': 0.22311727217573027}
# {'MAE': MAE: 0.035722, 'Step': 19780, 'Prediction': 0.24454625268878333}
# {'MAE': MAE: 0.035723, 'Step': 19781, 'Prediction': 0.2500175699374955}
# {'MAE': MAE: 0.035724, 'Step': 19782, 'Prediction': 0.24846706152094905}
# {'MAE': MAE: 0.035724, 'Step': 19783, 'Prediction': 0.25525756955139733}
# {'MAE': MAE: 0.035722, 'Step': 19784, 'Prediction': 0.269847509299319}
# {'MAE': MAE: 0.035723, 'Step': 19785, 'Prediction': 0.28675613920963083}
# {'MAE': MAE: 0.035725, 'Step': 19786, 'Prediction': 0.29824367869683605}
# {'MAE': MAE: 0.035725, 'Step': 19787, 'Prediction': 0.3094050044423113}
# {'MAE': MAE: 0.035724, 'Step': 19788, 'Prediction': 0.31978754747308974}
# {'MAE': MAE: 0.035724, 'Step': 19789, 'Prediction': 0.32851841417700717}
# {'MAE': MAE: 0.035727, 'Step': 19790, 'Prediction': 0.3352560863563484}
# {'MAE': MAE: 0.035729, 'Step': 19791, 'Prediction': 0.13417026690339}
# {'MAE': MAE: 0.035728, 'Step': 19792, 'Prediction': 0.14354342948873838}
# {'MAE': MAE: 0.035727, 'Step': 19793, 'Prediction': 0.1530854236062012}
# {'MAE': MAE: 0.035727, 'Step': 19794, 'Prediction': 0.16088016037134467}
# {'MAE': MAE: 0.035728, 'Step': 19795, 'Prediction': 0.1684228076718569}
# {'MAE': MAE: 0.03573, 'Step': 19796, 'Prediction': 0.17576100132646977}
# {'MAE': MAE: 0.03573, 'Step': 19797, 'Prediction': 0.18357103320610765}
# {'MAE': MAE: 0.035729, 'Step': 19798, 'Prediction': 0.1996591628794828}
# {'MAE': MAE: 0.035728, 'Step': 19799, 'Prediction': 0.20947508884819946}
# {'MAE': MAE: 0.035727, 'Step': 19800, 'Prediction': 0.20735172804568208}
# {'MAE': MAE: 0.035725, 'Step': 19801, 'Prediction': 0.20724862570052766}
# {'MAE': MAE: 0.035724, 'Step': 19802, 'Prediction': 0.2318152571424757}
# {'MAE': MAE: 0.035724, 'Step': 19803, 'Prediction': 0.22650797952858454}
# {'MAE': MAE: 0.035724, 'Step': 19804, 'Prediction': 0.23591626461389936}
# {'MAE': MAE: 0.035724, 'Step': 19805, 'Prediction': 0.24375804427113582}
# {'MAE': MAE: 0.035726, 'Step': 19806, 'Prediction': 0.2517864511863162}
# {'MAE': MAE: 0.035727, 'Step': 19807, 'Prediction': 0.2593965708112937}
# {'MAE': MAE: 0.035726, 'Step': 19808, 'Prediction': 0.26759064777046143}
# {'MAE': MAE: 0.035726, 'Step': 19809, 'Prediction': 0.2927095107700389}
# {'MAE': MAE: 0.035727, 'Step': 19810, 'Prediction': 0.3039718279780471}
# {'MAE': MAE: 0.035728, 'Step': 19811, 'Prediction': 0.31325245173093275}
# {'MAE': MAE: 0.035727, 'Step': 19812, 'Prediction': 0.3230079530836253}
# {'MAE': MAE: 0.035727, 'Step': 19813, 'Prediction': 0.3323500674916087}
# {'MAE': MAE: 0.03573, 'Step': 19814, 'Prediction': 0.3377456201652703}
# {'MAE': MAE: 0.035732, 'Step': 19815, 'Prediction': 0.1370176728133503}
# {'MAE': MAE: 0.035731, 'Step': 19816, 'Prediction': 0.14736429660993394}
# {'MAE': MAE: 0.03573, 'Step': 19817, 'Prediction': 0.15800751142772862}
# {'MAE': MAE: 0.03573, 'Step': 19818, 'Prediction': 0.16558957930580592}
# {'MAE': MAE: 0.035731, 'Step': 19819, 'Prediction': 0.1731840540595041}
# {'MAE': MAE: 0.035733, 'Step': 19820, 'Prediction': 0.18102678641660852}
# {'MAE': MAE: 0.035733, 'Step': 19821, 'Prediction': 0.1891163817518649}
# {'MAE': MAE: 0.035732, 'Step': 19822, 'Prediction': 0.20513114068664925}
# {'MAE': MAE: 0.035732, 'Step': 19823, 'Prediction': 0.20234981760970505}
# {'MAE': MAE: 0.035731, 'Step': 19824, 'Prediction': 0.20271359324902294}
# {'MAE': MAE: 0.03573, 'Step': 19825, 'Prediction': 0.2120098446286896}
# {'MAE': MAE: 0.035729, 'Step': 19826, 'Prediction': 0.2198433792464458}
# {'MAE': MAE: 0.035729, 'Step': 19827, 'Prediction': 0.22766360480011608}
# {'MAE': MAE: 0.035729, 'Step': 19828, 'Prediction': 0.2357622838672919}
# {'MAE': MAE: 0.03573, 'Step': 19829, 'Prediction': 0.2442567726104212}
# {'MAE': MAE: 0.035731, 'Step': 19830, 'Prediction': 0.25090539371105913}
# {'MAE': MAE: 0.035733, 'Step': 19831, 'Prediction': 0.25979908788270634}
# {'MAE': MAE: 0.035733, 'Step': 19832, 'Prediction': 0.26988387168031147}
# {'MAE': MAE: 0.035732, 'Step': 19833, 'Prediction': 0.2940817316228857}
# {'MAE': MAE: 0.035732, 'Step': 19834, 'Prediction': 0.3045366811845169}
# {'MAE': MAE: 0.035733, 'Step': 19835, 'Prediction': 0.31357209036536693}
# {'MAE': MAE: 0.035732, 'Step': 19836, 'Prediction': 0.32252813865734875}
# {'MAE': MAE: 0.035731, 'Step': 19837, 'Prediction': 0.3306345094077695}
# {'MAE': MAE: 0.035734, 'Step': 19838, 'Prediction': 0.3357453970942367}
# {'MAE': MAE: 0.035736, 'Step': 19839, 'Prediction': 0.13606067545054576}
# {'MAE': MAE: 0.035735, 'Step': 19840, 'Prediction': 0.143965743352281}
# {'MAE': MAE: 0.035734, 'Step': 19841, 'Prediction': 0.15186877449368602}
# {'MAE': MAE: 0.035734, 'Step': 19842, 'Prediction': 0.16033010843764195}
# {'MAE': MAE: 0.035735, 'Step': 19843, 'Prediction': 0.16676809008011562}
# {'MAE': MAE: 0.035736, 'Step': 19844, 'Prediction': 0.1741668382248859}
# {'MAE': MAE: 0.035736, 'Step': 19845, 'Prediction': 0.18168220378392214}
# {'MAE': MAE: 0.035735, 'Step': 19846, 'Prediction': 0.1971996927620786}
# {'MAE': MAE: 0.035735, 'Step': 19847, 'Prediction': 0.20608585326900672}
# {'MAE': MAE: 0.035734, 'Step': 19848, 'Prediction': 0.21945001480587134}
# {'MAE': MAE: 0.035732, 'Step': 19849, 'Prediction': 0.21023098673735197}
# {'MAE': MAE: 0.035731, 'Step': 19850, 'Prediction': 0.21713895707695144}
# {'MAE': MAE: 0.035731, 'Step': 19851, 'Prediction': 0.22655783276210875}
# {'MAE': MAE: 0.03573, 'Step': 19852, 'Prediction': 0.23468392141223207}
# {'MAE': MAE: 0.035731, 'Step': 19853, 'Prediction': 0.24497271619270128}
# {'MAE': MAE: 0.035732, 'Step': 19854, 'Prediction': 0.2504103356256933}
# {'MAE': MAE: 0.035732, 'Step': 19855, 'Prediction': 0.25645963767321217}
# {'MAE': MAE: 0.035732, 'Step': 19856, 'Prediction': 0.26596837836891446}
# {'MAE': MAE: 0.035731, 'Step': 19857, 'Prediction': 0.2920425222278133}
# {'MAE': MAE: 0.035732, 'Step': 19858, 'Prediction': 0.3034866179365675}
# {'MAE': MAE: 0.035733, 'Step': 19859, 'Prediction': 0.31313633642991634}
# {'MAE': MAE: 0.035732, 'Step': 19860, 'Prediction': 0.32348238897813286}
# {'MAE': MAE: 0.035731, 'Step': 19861, 'Prediction': 0.3315711895453319}
# {'MAE': MAE: 0.035734, 'Step': 19862, 'Prediction': 0.338122357500046}
# {'MAE': MAE: 0.035736, 'Step': 19863, 'Prediction': 0.1378541459268218}
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_70472\2862835537.py:57: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(mdates.date2num(df['DateTime']), df['MeanEnergyConsumption'], linestyle='-', marker=None, alpha=0.5, label='Actual Values')
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_70472\2862835537.py:59: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(mdates.date2num(timestamps), predictions, linestyle='-', marker=None, alpha=0.5, label='Predictions')
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_70472\2862835537.py:97: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(mdates.date2num(week_data['DateTime']), week_data['MeanEnergyConsumption'], linestyle='-', marker=None, label='Actual Values')
# C:\Users\Stijn\AppData\Local\Temp\ipykernel_70472\2862835537.py:100: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(mdates.date2num(week_predictions['DateTime']), week_predictions['Predictions'], linestyle='-', marker=None, label='Predictions')

# %%
#2018-02-04 22:45:00,10246.8760149   ,19070.7497393,0.25,0,0,0,0,1,0,0,0,1,0,0,0
#2018-02-04 23:00:00,10247.0859759    ,19070.7497393,0.2,0,0,0,0,1,0,0,0,1,0,0,0

print(model['LinearRegression'].weights)
print(model['LinearRegression'].intercept)

{"production": 0.2099, "temp": 0.2, "holiday": 0, "season_Autumn": 0, "season_Spring": 0, "season_Summer": 0, "season_Winter": 1, "hour_of_day": 4, "month": 2, "day_of_week": 2}

new_data = {}
print(model)
# Make a prediction on the new data
prediction = model.predict_one(new_data)
print("The predicted consumption is:")
print(prediction)
# Out:
# {'cloud_cover_low': -0.0002241714513033325, 'day_of_week': 0.0059868822429343, 'temperature_2m': -0.001484222088470855, 'sunshine_duration': -0.005681596962910837, 'hour_of_day': 0.05782923098948397, 'is_day': 0.0021236900770381147, 'month': 0.0055373824490955815, 'cloud_cover_mid': -0.00022482019639538098, 'cloud_cover_high': 0.0008517310754736896, 'cloud_cover': -0.0009686848664958382, 'precipitation': -0.00036051781374313844}
# 0.2300552012947462
# ['cloud_cover', 'cloud_cover_high', 'cloud_cover_low', 'cloud_cover_mid', 'day_of_week', 'hour_of_day', 'is_day', 'month', 'precipitation', 'sunshine_duration', 'temperature_2m'] | StandardScaler | LinearRegression
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 12
#      10 print(model)
#      11 # Make a prediction on the new data
# ---> 12 prediction = model.predict_one(new_data)
#      13 print("The predicted consumption is:")
#      14 print(prediction)
#
# File c:\Users\Stijn\AppData\Local\Programs\Python\Python310\lib\site-packages\river\compose\pipeline.py:533, in Pipeline.predict_one(self, x, **params)
#     524 def predict_one(self, x: dict, **params):
#     525     """Call `transform_one` on the first steps and `predict_one` on the last step.
#     526
#     527     Parameters
#    (...)
#     531
#     532     """
# --> 533     x, last_step = self._transform_one(x)
#     534     return last_step.predict_one(x, **params)
#
# File c:\Users\Stijn\AppData\Local\Programs\Python\Python310\lib\site-packages\river\compose\pipeline.py:504, in Pipeline._transform_one(self, x)
#     501         elif not t._supervised:
#     502             t.learn_one(x)
# --> 504     x = t.transform_one(x)
#     506 last_step = next(steps)
#     507 return x, last_step
#
# File c:\Users\Stijn\AppData\Local\Programs\Python\Python310\lib\site-packages\river\compose\select.py:131, in Select.transform_one(self, x)
#     130 def transform_one(self, x):
# --> 131     return {i: x[i] for i in self.keys}
#
# File c:\Users\Stijn\AppData\Local\Programs\Python\Python310\lib\site-packages\river\compose\select.py:131, in <dictcomp>(.0)
#     130 def transform_one(self, x):
# --> 131     return {i: x[i] for i in self.keys}
#
# KeyError: 'cloud_cover_low'

# %%
from river import optim
from river import evaluate
from sklearn.model_selection import ParameterGrid
stream = iter(df.itertuples(index=False))
stream = iter([(x._asdict(), y) for x, y in zip(df.drop('MeanEnergyConsumption', axis=1).itertuples(index=False), df['MeanEnergyConsumption'])])
# Define the parameter grid

learning_rate = [1,2,0.5,4,10,0.1]
learning_rate = [0.7,0.75,0.6,0.71,0.69,0.72]

#multiply the learning values by 2
learning_rate_actual = [x * 0.001 for x in learning_rate]

print(learning_rate)
print(learning_rate_actual)

param_grid = {'learning_rate': learning_rate_actual}

# Initialize the best MAE and learning rate
best_mae = float('inf')
best_lr = None


def get_maetest(mae):
    return float(str(mae).split(" ")[1])



# Iterate over the parameter grid
for params in ParameterGrid(param_grid):
    # Create a new model with the current learning rate
    model = compose.Select('hour_of_day', 'month', 'day_of_week','temperature_2m', 'precipitation','cloud_cover','cloud_cover_low','cloud_cover_mid','cloud_cover_high','is_day','sunshine_duration')
    model |= preprocessing.StandardScaler()
    model |= linear_model.LinearRegression(optimizer=optim.SGD(params['learning_rate']))
    
    # Evaluate the model
    mae = evaluate.progressive_val_score(
        dataset=stream,
        model=model.clone(),
        metric=metrics.MAE(),
        moment='DateTime',
        delay=dt.timedelta(days=7),
        step=1,
    )
    print(mae)
    #print(type(mae.get()))
    stream = iter(df.itertuples(index=False))
    stream = iter([(x._asdict(), y) for x, y in zip(df.drop('MeanEnergyConsumption', axis=1).itertuples(index=False), df['MeanEnergyConsumption'])])
    #print(type(best_mae))
    
    #print(float(str(mae).split(" ")[1]))
    # If the current MAE is better than the best MAE, update the best MAE and learning rate
    #print(f'Learning rate: {params["learning_rate"]}, MAE: {(mae)}')
    if mae.get() != 0 and mae.get() < best_mae:
        best_mae = mae.get()
        best_lr = params['learning_rate']

print(f'Best MAE: {best_mae}')
print(f'Best learning rate: {best_lr}')
# Out:
# [0.7, 0.75, 0.6, 0.71, 0.69, 0.72]
# [0.0007, 0.00075, 0.0006, 0.00071, 0.00069, 0.0007199999999999999]
# MAE: 0.035783
# MAE: 0.035787
# MAE: 0.035823
# MAE: 0.035783
# MAE: 0.035784
# MAE: 0.035783
# Best MAE: 0.03578253269955161
# Best learning rate: 0.00071

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
stream = iter(df.itertuples(index=False))
stream = iter([(x._asdict(), y) for x, y in zip(df.drop('consumption', axis=1).itertuples(index=False), df['consumption'])])
print(next(stream))



# Initialize an empty list to store the predictions and their timestamps
predictions = []
timestamps = []

# Clone the model
model_clone = model.clone()

# Iterate over the stream
for x, y in stream:
    # Make a prediction
    y_pred = model_clone.predict_one(x)
    
    # Store the prediction and the timestamp (delayed by 24 hours)
    predictions.append(y_pred)
    timestamps.append(x['utc_timestamp'] + dt.timedelta(hours=24))
    
    # Update the model
    model_clone.learn_one(x, y)

#print the metrics
print(f'MAE: {metric.get()}')

# Plot the predictions
fig, ax = plt.subplots()
ax.plot_date(mdates.date2num(timestamps), predictions, linestyle='-', marker=None)

# Format the x-axis to display dates
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))

plt.show()
# Out:
# ({'utc_timestamp': Timestamp('2015-10-10 16:45:00'), 'production': 0.0, 'temp': 10.45, 'holiday': 0, 'season_Autumn': 1, 'season_Spring': 0, 'season_Summer': 0, 'season_Winter': 0, 'day_of_week_Friday': 0, 'day_of_week_Monday': 0, 'day_of_week_Saturday': 1, 'day_of_week_Sunday': 0, 'day_of_week_Thursday': 0, 'day_of_week_Tuesday': 0, 'day_of_week_Wednesday': 0, 'day_of_week': 5, 'hour_of_day': 16, 'month': 10}, 0.0396815708706)
# MAE: 0.0
# C:\Users\stijn\AppData\Local\Temp\ipykernel_28864\940865554.py:33: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot_date(mdates.date2num(timestamps), predictions, linestyle='-', marker=None)
